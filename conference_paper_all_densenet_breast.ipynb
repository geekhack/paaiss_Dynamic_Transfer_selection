# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SciPy
# Out:
# Requirement already satisfied: SciPy in /usr/local/lib/python3.6/dist-packages (1.5.4)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from SciPy) (1.19.5)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
import os
import statistics as stats
from collections import defaultdict
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50 as resnet50
from tensorflow.keras.applications.inception_v3 import InceptionV3 as inception
from tensorflow.keras.applications.vgg16 import VGG16 as vgg16
from tensorflow.keras.applications.densenet import DenseNet169 as densenet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, losses, optimizers
from tensorflow.keras.layers import Dense,Dropout,GlobalAveragePooling2D,Flatten,InputLayer, BatchNormalization, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# %%
##create a generator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,                          
        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
##datasets splicings
train_dataset  = train_datagen.flow_from_directory(directory = 'breast_data/Data/train',
                                                   target_size = (32,32),
                                                   class_mode = 'categorical',
                                                   batch_size = 64)

valid_dataset = valid_datagen.flow_from_directory(directory = 'breast_data/Data/valid',
                                                  target_size = (32,32),
                                                  class_mode = 'categorical',
                                                  batch_size = 64)

test_dataset = test_datagen.flow_from_directory(directory = 'breast_data/Data/test',
                                                  target_size = (32,32),
                                                  class_mode = 'categorical',
                                                  batch_size = 64)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
model_name = densenet
input_t =(32,32, 3)
model = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)

model2 = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)

model3 = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)
model_tune1 = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)
model_tune2 = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)
model_tune3 = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)
model_tune4 = model_name(include_top=False,
                   weights="imagenet",
                   input_shape=input_t)

# %%
# get the layer index
def getLayerIndex(model_i, layer_name):
    for pos, layer_g in enumerate(model_i.layers):
        if layer_g.name == layer_name:
            return pos

# %%
# get the convolved layers into an array for looping
convolved_layers = []

for layer in model.layers:

    t = np.array(layer.get_weights()).ndim
    array = np.array(layer.get_weights())
    if (model_name != resnet50) or (model_name != vgg16):
        if (len(array) > 0) and (t > 2):
            index = getLayerIndex(model, layer.name)
            # append the convolved layer
            convolved_layers.append(index)
            # print(str(len(array)) + "for:" + layer.name + "at index:" + str(index))
    if (model_name == resnet50) or (model_name == vgg16):
        if len(array) > 0 and (t != 2):
            index = getLayerIndex(model, layer.name)
            # append the convolved layer
            convolved_layers.append(index)
            # print(str(len(array)) + "for:" + layer.name + "at index:" + str(index))

# get the total number of weights in the array
total_layer_weights = 0
sum_positives = 0
sum_negatives = 0

# create a dictionary with layer index and positive values identified
layer_positives_dict = defaultdict(list)

# create a dictionary for storing the layers and their +ve values probabilities
layer_probs_dict = defaultdict(list)

# %%
# list the convolved layers
for c_layer in range(len(convolved_layers)):
    # create array for array matrices,feature values and convolved values for each layer
    layer_array_matrices = []
    layer_feature_sums = []
    layer_convolved_values_sum = []

    # get the arrays matrices(batches) pixel
    for i in range(len(model.layers[convolved_layers[c_layer]].get_weights()[0])):
        # get the values for each feature
        ######print("channels(image):"+str(len(model.layers[convolved_layers[c_layer]].get_weights()[0][i])))
        for x in range(len(model.layers[convolved_layers[c_layer]].get_weights()[0][i])):
            # return all the values in the convolutional feature
            total_array = np.array(model.layers[convolved_layers[c_layer]].get_weights()[0][i][x])
            # return all the negative values in the convolutional feature
            x2 = np.array(model.layers[convolved_layers[c_layer]].get_weights()[0][i][x]) < 0
            for c in range(len(x2)):
                ###print("all the trues in depth: " + str(c + 1) + " are for feature: " + str(x + 1))
                sum_negatives += sum(x2[c])
                # print(sum(x2[c]))
            # return all the values
            for y in range(len(total_array)):
                total_layer_weights += len(total_array[y])

            x1 = np.array(model.layers[convolved_layers[c_layer]].get_weights()[0][i][x]) > 0
            # get the values for each channel
            for a in range(len(x1)):
                value_pix = sum(x1[a])
                # get the positive values
                sum_positives += value_pix

                ######print(value_pix)
    list_sums = []
    list_sums.append((str(convolved_layers[c_layer]), sum_positives))
    layer_positives_dict.update(list_sums)

    # print the probabilities for each layer
    layer_pos_prob = sum_positives / total_layer_weights

    # create +ves values array
    positives_array = []
    for key, val in layer_positives_dict.items():
        # print(key, "corresponds to:",val," positive values")
        positives_array.append(val)
       
    list_layer_probs = []
    list_layer_probs.append((str(convolved_layers[c_layer]), layer_pos_prob))
    layer_probs_dict.update(list_layer_probs)

# %%
median_layer = stats.median(convolved_layers)

# create dictionary for storing selected median layers
second_layer_probs_dict = defaultdict(list)
# store the new list of layers to be matched with the mean probability
second_half_layers = []

# store all probabilities for the selected upper half layers
second_half_probs = []
# loop through the layers and print those layers above the median
for lyr, val in layer_probs_dict.items():
    # print(lyr, "Layer prob:", val)
    if int(lyr) > median_layer:
        # store the probabilities of the upper half selected convolved layers
        #print(lyr, "Layer prob:", val)
        # update the sum of selected layers probabilities
        second_half_probs.append(val)
        second_half_layers.append((lyr, val))
        second_layer_probs_dict.update(second_half_layers)

# get the mean of the layers
selected_layers_mean = stats.mean(second_half_probs)
final_selected_layers = []
# now get the final layers list whose value exceed the mean
for s_lyr, v in second_layer_probs_dict.items():
    # get the probabilities that are lower than the mean probability
    if v < selected_layers_mean:
        # store the probabilities of the upper half selected convolved layers
        final_selected_layers.append(s_lyr)

# %%
# for positive cosines similarities
pcs_h_layers =[332,223,153,406,93,195,58,188,2] #high cosine,,
pcs_l_layers =[514,528,521,493,535,570,577] #lower cosine
for sb_layer in model.layers:
    # sb_layer.trainable = False
    index = getLayerIndex(model, sb_layer.name)
    #for b in final_selected_layers:
    for b in pcs_h_layers:
        if b == index:
            sb_layer.trainable = True
            #print(str(sb_layer.name) + " and index is" + str(b))
            print(sb_layer.name,sb_layer.trainable)

#for negative cosine similarities
# for model 2
# for positive cosines similarities
ncs_h_layers =[570,210,335,363,528,521,2]
ncs_l_layers =[265,55,458,139,8,51] #lower cosine
for sbs_layer in model2.layers:
    # sb_layer.trainable = False
    index = getLayerIndex(model2, sbs_layer.name)
    #for b in final_selected_layers:
    for b in ncs_h_layers:
        if b == index:
            sb_layer.trainable = True
            #print(str(sb_layer.name) + " and index is" + str(b))
            print(sb_layer.name,sb_layer.trainable)

#for positive negative cosine similarities
# for model 3
pncs_h_layers =[118,584,535,528,83,55] #high cosine,,
pncs_l_layers =[2,363,265,272,349] #lower cosine
for sbs_layer in model3.layers:
    # sb_layer.trainable = False
    index = getLayerIndex(model3, sbs_layer.name)
    #for b in final_selected_layers:
    for b in pncs_h_layers:
        if b == index:
            sb_layer.trainable = True
            #print(str(sb_layer.name) + " and index is" + str(b))
            print(sb_layer.name,sb_layer.trainable)


#finetune by removeing the last layer
for lst_layer in model_tune1.layers[:-2]:
    lst_layer.trainable = False
    
####end of the last layer
#finetune by removeing the 2nd last layer
for scnd_st_layer in model_tune2.layers[:-3]:
    scnd_st_layer.trainable = False
    
####end of the last layer
#finetune by removeing the 3rd last layer
for thrd_layer in model_tune3.layers[:-4]:
    thrd_layer.trainable = False
    

    
####end of the last layer
#for feature extraction
for ftr_layer in model_tune4.layers:
    ftr_layer.trainable = False

# try the transfer learning model
to_res = (224, 224)
# Out:
# conv1/conv True
# conv3_block1_2_conv True
# conv3_block6_2_conv True
# conv4_block2_2_conv True
# conv4_block7_2_conv True
# conv4_block8_2_conv True
# conv4_block12_2_conv True
# conv4_block28_1_conv True
# conv5_block6_1_conv True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True
# relu True

# %%
t_model = Sequential()
t_model.add(model)
t_model.add(Flatten())
#t_model.add(layers.BatchNormalization())
t_model.add(layers.Dense(64, activation='relu'))
t_model.add(layers.Dropout(0.5))
#t_model.add(layers.BatchNormalization())
t_model.add(layers.Dense(4, activation='softmax'))


#for model 2
t_model2 = Sequential()
t_model2.add(model2)
t_model2.add(Flatten())
#t_model2.add(layers.BatchNormalization())
t_model2.add(layers.Dense(64, activation='relu'))
t_model2.add(layers.Dropout(0.5))
#t_model2.add(layers.BatchNormalization())
t_model2.add(layers.Dense(4, activation='softmax'))


#for model 2
t_model3 = Sequential()
t_model3.add(model3)
t_model3.add(Flatten())
#t_model3.add(layers.BatchNormalization())
t_model3.add(layers.Dense(64, activation='relu'))
t_model3.add(layers.Dropout(0.5))
#t_model3.add(layers.BatchNormalization())
t_model3.add(layers.Dense(4, activation='softmax'))


#for model 2
t_model4 = Sequential()
t_model4.add(model_tune1)
t_model4.add(Flatten())
#t_model4.add(layers.BatchNormalization())
t_model4.add(layers.Dense(64, activation='relu'))
t_model4.add(layers.Dropout(0.5))
#t_model4.add(layers.BatchNormalization())
t_model4.add(layers.Dense(4, activation='softmax'))

#for model 2
t_model5 = Sequential()
t_model5.add(model_tune2)
t_model5.add(Flatten())
#t_model5.add(layers.BatchNormalization())
t_model5.add(layers.Dense(64, activation='relu'))
t_model5.add(layers.Dropout(0.5))
#t_model5.add(layers.BatchNormalization())
t_model5.add(layers.Dense(4, activation='softmax'))

#for model 2
t_model6 = Sequential()
t_model6.add(model_tune3)
t_model6.add(Flatten())
#t_model6.add(layers.BatchNormalization())
t_model6.add(layers.Dense(64, activation='relu'))
t_model6.add(layers.Dropout(0.5))
#t_model6.add(layers.BatchNormalization())
t_model6.add(layers.Dense(4, activation='softmax'))


#for model 2
t_model7 = Sequential()
t_model7.add(model_tune3)
t_model7.add(Flatten())
#t_model7.add(layers.BatchNormalization())
t_model7.add(layers.Dense(64, activation='relu'))
t_model7.add(layers.Dropout(0.5))
#t_model7.add(layers.BatchNormalization())
t_model7.add(layers.Dense(4, activation='softmax'))

# %%
#positive cosine similarity
t_model.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history = t_model.fit(train_dataset,shuffle=True,validation_data=valid_dataset,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 30s 946ms/step - loss: 1.8857 - accuracy: 0.3059 - val_loss: 1.4855 - val_accuracy: 0.2639
# Epoch 2/100
# 10/10 [==============================] - 4s 356ms/step - loss: 1.4968 - accuracy: 0.3959 - val_loss: 1.4204 - val_accuracy: 0.3056
# Epoch 3/100
# 10/10 [==============================] - 4s 342ms/step - loss: 1.3375 - accuracy: 0.4193 - val_loss: 1.3945 - val_accuracy: 0.3056
# Epoch 4/100
# 10/10 [==============================] - 4s 362ms/step - loss: 1.2460 - accuracy: 0.4702 - val_loss: 1.3941 - val_accuracy: 0.3194
# Epoch 5/100
# 10/10 [==============================] - 4s 348ms/step - loss: 1.1481 - accuracy: 0.5081 - val_loss: 1.4069 - val_accuracy: 0.2778
# Epoch 6/100
# 10/10 [==============================] - 4s 356ms/step - loss: 1.0358 - accuracy: 0.5687 - val_loss: 1.4260 - val_accuracy: 0.2500
# Epoch 7/100
# 10/10 [==============================] - 4s 374ms/step - loss: 1.0134 - accuracy: 0.5706 - val_loss: 1.4554 - val_accuracy: 0.2361
# Epoch 8/100
# 10/10 [==============================] - 4s 356ms/step - loss: 0.9518 - accuracy: 0.6164 - val_loss: 1.4661 - val_accuracy: 0.2639
# Epoch 9/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.8914 - accuracy: 0.6153 - val_loss: 1.4363 - val_accuracy: 0.2500
# Epoch 10/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9387 - accuracy: 0.5778 - val_loss: 1.4251 - val_accuracy: 0.2639
# Epoch 11/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9206 - accuracy: 0.6219 - val_loss: 1.4189 - val_accuracy: 0.3056
# Epoch 12/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.8212 - accuracy: 0.6478 - val_loss: 1.4156 - val_accuracy: 0.3056
# Epoch 13/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.8145 - accuracy: 0.6588 - val_loss: 1.4061 - val_accuracy: 0.3194
# Epoch 14/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.7706 - accuracy: 0.6699 - val_loss: 1.4167 - val_accuracy: 0.3194
# Epoch 15/100
# 10/10 [==============================] - 4s 356ms/step - loss: 0.7552 - accuracy: 0.6857 - val_loss: 1.4047 - val_accuracy: 0.3194
# Epoch 16/100
# 10/10 [==============================] - 4s 344ms/step - loss: 0.7781 - accuracy: 0.6635 - val_loss: 1.3955 - val_accuracy: 0.3472
# Epoch 17/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.7860 - accuracy: 0.6691 - val_loss: 1.3591 - val_accuracy: 0.3750
# Epoch 18/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.6786 - accuracy: 0.7305 - val_loss: 1.3279 - val_accuracy: 0.3750
# Epoch 19/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.7043 - accuracy: 0.6920 - val_loss: 1.3278 - val_accuracy: 0.3750
# Epoch 20/100
# 10/10 [==============================] - 3s 351ms/step - loss: 0.6611 - accuracy: 0.7335 - val_loss: 1.3490 - val_accuracy: 0.3472
# Epoch 21/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.7030 - accuracy: 0.7057 - val_loss: 1.3769 - val_accuracy: 0.3472
# Epoch 22/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.6672 - accuracy: 0.7261 - val_loss: 1.3894 - val_accuracy: 0.3472
# Epoch 23/100
# 10/10 [==============================] - 4s 374ms/step - loss: 0.6564 - accuracy: 0.7156 - val_loss: 1.4209 - val_accuracy: 0.3333
# Epoch 24/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.5755 - accuracy: 0.7392 - val_loss: 1.4275 - val_accuracy: 0.3333
# Epoch 25/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.6291 - accuracy: 0.7590 - val_loss: 1.3992 - val_accuracy: 0.3472
# Epoch 26/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.5972 - accuracy: 0.7461 - val_loss: 1.4004 - val_accuracy: 0.3333
# Epoch 27/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.5875 - accuracy: 0.7592 - val_loss: 1.3750 - val_accuracy: 0.3750
# Epoch 28/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.5886 - accuracy: 0.7660 - val_loss: 1.3958 - val_accuracy: 0.4028
# Epoch 29/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.5314 - accuracy: 0.7869 - val_loss: 1.4334 - val_accuracy: 0.4028
# Epoch 30/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.5031 - accuracy: 0.7840 - val_loss: 1.4929 - val_accuracy: 0.4028
# Epoch 31/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.5009 - accuracy: 0.7848 - val_loss: 1.3902 - val_accuracy: 0.4306
# Epoch 32/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.5381 - accuracy: 0.7938 - val_loss: 1.3755 - val_accuracy: 0.4306
# Epoch 33/100
# 10/10 [==============================] - 4s 338ms/step - loss: 0.5338 - accuracy: 0.7887 - val_loss: 1.4046 - val_accuracy: 0.4306
# Epoch 34/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.4848 - accuracy: 0.8331 - val_loss: 1.4407 - val_accuracy: 0.4028
# Epoch 35/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.4563 - accuracy: 0.8064 - val_loss: 1.4047 - val_accuracy: 0.4028
# Epoch 36/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.4460 - accuracy: 0.8190 - val_loss: 1.3858 - val_accuracy: 0.4167
# Epoch 37/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.4120 - accuracy: 0.8224 - val_loss: 1.4464 - val_accuracy: 0.4028
# Epoch 38/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.4203 - accuracy: 0.8436 - val_loss: 1.4184 - val_accuracy: 0.4167
# Epoch 39/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.4074 - accuracy: 0.8562 - val_loss: 1.3564 - val_accuracy: 0.4167
# Epoch 40/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.4357 - accuracy: 0.8172 - val_loss: 1.3911 - val_accuracy: 0.4306
# Epoch 41/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.4233 - accuracy: 0.8356 - val_loss: 1.3837 - val_accuracy: 0.4722
# Epoch 42/100
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3480 - accuracy: 0.8724 - val_loss: 1.2746 - val_accuracy: 0.4583
# Epoch 43/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.3549 - accuracy: 0.8809 - val_loss: 1.2488 - val_accuracy: 0.4722
# Epoch 44/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.3230 - accuracy: 0.8750 - val_loss: 1.1747 - val_accuracy: 0.5556
# Epoch 45/100
# 10/10 [==============================] - 4s 390ms/step - loss: 0.3434 - accuracy: 0.8742 - val_loss: 1.1557 - val_accuracy: 0.5694
# Epoch 46/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.3995 - accuracy: 0.8542 - val_loss: 1.1850 - val_accuracy: 0.5833
# Epoch 47/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.3029 - accuracy: 0.8952 - val_loss: 1.1993 - val_accuracy: 0.5833
# Epoch 48/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.3069 - accuracy: 0.8967 - val_loss: 1.2356 - val_accuracy: 0.5833
# Epoch 49/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.3090 - accuracy: 0.8840 - val_loss: 1.2153 - val_accuracy: 0.5833
# Epoch 50/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.3485 - accuracy: 0.8660 - val_loss: 1.0972 - val_accuracy: 0.6389
# Epoch 51/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.3153 - accuracy: 0.8661 - val_loss: 1.0040 - val_accuracy: 0.6944
# Epoch 52/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.2943 - accuracy: 0.8991 - val_loss: 0.9709 - val_accuracy: 0.7083
# Epoch 53/100
# 10/10 [==============================] - 4s 356ms/step - loss: 0.2961 - accuracy: 0.8899 - val_loss: 0.9807 - val_accuracy: 0.7083
# Epoch 54/100
# 10/10 [==============================] - 4s 344ms/step - loss: 0.3327 - accuracy: 0.8724 - val_loss: 0.9034 - val_accuracy: 0.6667
# Epoch 55/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.3266 - accuracy: 0.8807 - val_loss: 0.8378 - val_accuracy: 0.7083
# Epoch 56/100
# 10/10 [==============================] - 4s 427ms/step - loss: 0.2959 - accuracy: 0.8752 - val_loss: 0.8336 - val_accuracy: 0.7083
# Epoch 57/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.2856 - accuracy: 0.8924 - val_loss: 0.9051 - val_accuracy: 0.6667
# Epoch 58/100
# 10/10 [==============================] - 4s 336ms/step - loss: 0.3078 - accuracy: 0.8776 - val_loss: 0.8907 - val_accuracy: 0.7083
# Epoch 59/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2868 - accuracy: 0.9168 - val_loss: 0.8379 - val_accuracy: 0.7361
# Epoch 60/100
# 10/10 [==============================] - 4s 340ms/step - loss: 0.3392 - accuracy: 0.8862 - val_loss: 0.9249 - val_accuracy: 0.7222
# Epoch 61/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.2943 - accuracy: 0.9029 - val_loss: 1.0770 - val_accuracy: 0.6667
# Epoch 62/100
# 10/10 [==============================] - 4s 345ms/step - loss: 0.2885 - accuracy: 0.8985 - val_loss: 1.0129 - val_accuracy: 0.6806
# Epoch 63/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.2855 - accuracy: 0.8980 - val_loss: 0.9383 - val_accuracy: 0.7083
# Epoch 64/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.2941 - accuracy: 0.8864 - val_loss: 0.8613 - val_accuracy: 0.7361
# Epoch 65/100
# 10/10 [==============================] - 4s 347ms/step - loss: 0.2324 - accuracy: 0.9164 - val_loss: 0.7952 - val_accuracy: 0.7500
# Epoch 66/100
# 10/10 [==============================] - 4s 343ms/step - loss: 0.2076 - accuracy: 0.9263 - val_loss: 0.8206 - val_accuracy: 0.7778
# Epoch 67/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2327 - accuracy: 0.9213 - val_loss: 0.8792 - val_accuracy: 0.7778
# Epoch 68/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.2230 - accuracy: 0.9222 - val_loss: 1.0444 - val_accuracy: 0.6944
# Epoch 69/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2335 - accuracy: 0.9007 - val_loss: 1.2306 - val_accuracy: 0.6944
# Epoch 70/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2066 - accuracy: 0.9302 - val_loss: 1.1684 - val_accuracy: 0.7083
# Epoch 71/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.2182 - accuracy: 0.9335 - val_loss: 1.1014 - val_accuracy: 0.7500
# Epoch 72/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.1629 - accuracy: 0.9362 - val_loss: 1.0569 - val_accuracy: 0.7361
# Epoch 73/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.2096 - accuracy: 0.9274 - val_loss: 0.9617 - val_accuracy: 0.7917
# Epoch 74/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.1581 - accuracy: 0.9425 - val_loss: 0.9938 - val_accuracy: 0.7917
# Epoch 75/100
# 10/10 [==============================] - 3s 327ms/step - loss: 0.2243 - accuracy: 0.9351 - val_loss: 0.9870 - val_accuracy: 0.7639
# Epoch 76/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.2054 - accuracy: 0.9145 - val_loss: 1.0432 - val_accuracy: 0.7361
# Epoch 77/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.1868 - accuracy: 0.9324 - val_loss: 1.0401 - val_accuracy: 0.7639
# Epoch 78/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.1399 - accuracy: 0.9594 - val_loss: 1.0307 - val_accuracy: 0.7917
# Epoch 79/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.1801 - accuracy: 0.9406 - val_loss: 1.0455 - val_accuracy: 0.7778
# Epoch 80/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.1582 - accuracy: 0.9375 - val_loss: 1.0550 - val_accuracy: 0.7083
# Epoch 81/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.1414 - accuracy: 0.9574 - val_loss: 1.2462 - val_accuracy: 0.6806
# Epoch 82/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.1814 - accuracy: 0.9214 - val_loss: 1.3588 - val_accuracy: 0.6528
# Epoch 83/100
# 10/10 [==============================] - 3s 320ms/step - loss: 0.1660 - accuracy: 0.9295 - val_loss: 1.2946 - val_accuracy: 0.6667
# Epoch 84/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.1422 - accuracy: 0.9496 - val_loss: 1.2399 - val_accuracy: 0.6806
# Epoch 85/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.1793 - accuracy: 0.9409 - val_loss: 1.1455 - val_accuracy: 0.7361
# Epoch 86/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.1752 - accuracy: 0.9431 - val_loss: 1.0232 - val_accuracy: 0.7639
# Epoch 87/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.1729 - accuracy: 0.9451 - val_loss: 0.9503 - val_accuracy: 0.7917
# Epoch 88/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1572 - accuracy: 0.9529 - val_loss: 0.9918 - val_accuracy: 0.7917
# Epoch 89/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.1568 - accuracy: 0.9646 - val_loss: 0.9534 - val_accuracy: 0.7639
# Epoch 90/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.1471 - accuracy: 0.9544 - val_loss: 0.9262 - val_accuracy: 0.7778
# Epoch 91/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.1667 - accuracy: 0.9310 - val_loss: 0.9227 - val_accuracy: 0.7917
# Epoch 92/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1537 - accuracy: 0.9617 - val_loss: 0.9270 - val_accuracy: 0.8056
# Epoch 93/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.1471 - accuracy: 0.9568 - val_loss: 0.9419 - val_accuracy: 0.7778
# Epoch 94/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.1529 - accuracy: 0.9415 - val_loss: 0.8101 - val_accuracy: 0.8056
# Epoch 95/100
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1230 - accuracy: 0.9458 - val_loss: 0.8636 - val_accuracy: 0.7917
# Epoch 96/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.1623 - accuracy: 0.9426 - val_loss: 0.8727 - val_accuracy: 0.7778
# Epoch 97/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1169 - accuracy: 0.9651 - val_loss: 0.8324 - val_accuracy: 0.7778
# Epoch 98/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.1642 - accuracy: 0.9237 - val_loss: 0.8336 - val_accuracy: 0.8056
# Epoch 99/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1413 - accuracy: 0.9420 - val_loss: 0.8782 - val_accuracy: 0.7917
# Epoch 100/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1483 - accuracy: 0.9505 - val_loss: 0.9129 - val_accuracy: 0.7778

# %%
#negative cosine similarity look
#for model2
t_model2.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history2 = t_model2.fit(train_dataset,shuffle=True,validation_data=valid_dataset,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 25s 722ms/step - loss: 1.8144 - accuracy: 0.2185 - val_loss: 1.3980 - val_accuracy: 0.3056
# Epoch 2/100
# 10/10 [==============================] - 4s 341ms/step - loss: 1.4660 - accuracy: 0.3676 - val_loss: 1.3342 - val_accuracy: 0.2917
# Epoch 3/100
# 10/10 [==============================] - 4s 341ms/step - loss: 1.2737 - accuracy: 0.4460 - val_loss: 1.2990 - val_accuracy: 0.2917
# Epoch 4/100
# 10/10 [==============================] - 4s 345ms/step - loss: 1.2044 - accuracy: 0.5023 - val_loss: 1.2875 - val_accuracy: 0.2917
# Epoch 5/100
# 10/10 [==============================] - 3s 349ms/step - loss: 1.0979 - accuracy: 0.5046 - val_loss: 1.2974 - val_accuracy: 0.3333
# Epoch 6/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.0403 - accuracy: 0.5595 - val_loss: 1.2763 - val_accuracy: 0.3472
# Epoch 7/100
# 10/10 [==============================] - 3s 318ms/step - loss: 1.0461 - accuracy: 0.5516 - val_loss: 1.2315 - val_accuracy: 0.3750
# Epoch 8/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.9816 - accuracy: 0.5892 - val_loss: 1.2190 - val_accuracy: 0.4028
# Epoch 9/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9981 - accuracy: 0.5650 - val_loss: 1.2135 - val_accuracy: 0.4167
# Epoch 10/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.8761 - accuracy: 0.6123 - val_loss: 1.2113 - val_accuracy: 0.4444
# Epoch 11/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.8556 - accuracy: 0.5956 - val_loss: 1.2233 - val_accuracy: 0.3750
# Epoch 12/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.8340 - accuracy: 0.6244 - val_loss: 1.2371 - val_accuracy: 0.4167
# Epoch 13/100
# 10/10 [==============================] - 3s 351ms/step - loss: 0.8376 - accuracy: 0.6145 - val_loss: 1.2138 - val_accuracy: 0.3889
# Epoch 14/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.7700 - accuracy: 0.6367 - val_loss: 1.2044 - val_accuracy: 0.3611
# Epoch 15/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.7602 - accuracy: 0.6580 - val_loss: 1.1922 - val_accuracy: 0.4167
# Epoch 16/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.7713 - accuracy: 0.6809 - val_loss: 1.1931 - val_accuracy: 0.4028
# Epoch 17/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.7743 - accuracy: 0.6804 - val_loss: 1.2097 - val_accuracy: 0.3611
# Epoch 18/100
# 10/10 [==============================] - 4s 343ms/step - loss: 0.7007 - accuracy: 0.6877 - val_loss: 1.2261 - val_accuracy: 0.3611
# Epoch 19/100
# 10/10 [==============================] - 4s 358ms/step - loss: 0.6996 - accuracy: 0.6784 - val_loss: 1.2250 - val_accuracy: 0.3750
# Epoch 20/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.6525 - accuracy: 0.7249 - val_loss: 1.2139 - val_accuracy: 0.3611
# Epoch 21/100
# 10/10 [==============================] - 4s 373ms/step - loss: 0.6124 - accuracy: 0.7293 - val_loss: 1.2138 - val_accuracy: 0.4167
# Epoch 22/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.6130 - accuracy: 0.7335 - val_loss: 1.2111 - val_accuracy: 0.4028
# Epoch 23/100
# 10/10 [==============================] - 4s 342ms/step - loss: 0.5753 - accuracy: 0.7428 - val_loss: 1.2453 - val_accuracy: 0.3611
# Epoch 24/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.6256 - accuracy: 0.7397 - val_loss: 1.2354 - val_accuracy: 0.3611
# Epoch 25/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.5396 - accuracy: 0.7794 - val_loss: 1.2217 - val_accuracy: 0.3472
# Epoch 26/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.5391 - accuracy: 0.7943 - val_loss: 1.1599 - val_accuracy: 0.3889
# Epoch 27/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.5567 - accuracy: 0.7604 - val_loss: 1.1319 - val_accuracy: 0.4306
# Epoch 28/100
# 10/10 [==============================] - 4s 372ms/step - loss: 0.5528 - accuracy: 0.7681 - val_loss: 1.0597 - val_accuracy: 0.4861
# Epoch 29/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.5351 - accuracy: 0.7653 - val_loss: 1.0387 - val_accuracy: 0.4861
# Epoch 30/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.5306 - accuracy: 0.7762 - val_loss: 1.0579 - val_accuracy: 0.5000
# Epoch 31/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.5223 - accuracy: 0.7855 - val_loss: 1.0839 - val_accuracy: 0.5000
# Epoch 32/100
# 10/10 [==============================] - 4s 347ms/step - loss: 0.5161 - accuracy: 0.8137 - val_loss: 1.0576 - val_accuracy: 0.5000
# Epoch 33/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.4728 - accuracy: 0.8018 - val_loss: 1.0400 - val_accuracy: 0.5000
# Epoch 34/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.4737 - accuracy: 0.8233 - val_loss: 1.0083 - val_accuracy: 0.5000
# Epoch 35/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.4913 - accuracy: 0.7876 - val_loss: 0.9924 - val_accuracy: 0.5556
# Epoch 36/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4365 - accuracy: 0.8070 - val_loss: 0.9982 - val_accuracy: 0.5833
# Epoch 37/100
# 10/10 [==============================] - 4s 342ms/step - loss: 0.4173 - accuracy: 0.8153 - val_loss: 0.9941 - val_accuracy: 0.5139
# Epoch 38/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.4292 - accuracy: 0.8222 - val_loss: 1.0003 - val_accuracy: 0.4861
# Epoch 39/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.4131 - accuracy: 0.8285 - val_loss: 1.0320 - val_accuracy: 0.4722
# Epoch 40/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4395 - accuracy: 0.8366 - val_loss: 1.0286 - val_accuracy: 0.4722
# Epoch 41/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.3623 - accuracy: 0.8543 - val_loss: 1.0546 - val_accuracy: 0.4861
# Epoch 42/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.3773 - accuracy: 0.8558 - val_loss: 1.0121 - val_accuracy: 0.5139
# Epoch 43/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.3888 - accuracy: 0.8660 - val_loss: 0.9556 - val_accuracy: 0.5556
# Epoch 44/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.3918 - accuracy: 0.8553 - val_loss: 0.9203 - val_accuracy: 0.5417
# Epoch 45/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.3665 - accuracy: 0.8379 - val_loss: 0.8868 - val_accuracy: 0.5556
# Epoch 46/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.3530 - accuracy: 0.8517 - val_loss: 0.8397 - val_accuracy: 0.5833
# Epoch 47/100
# 10/10 [==============================] - 4s 341ms/step - loss: 0.3262 - accuracy: 0.8827 - val_loss: 0.8563 - val_accuracy: 0.5833
# Epoch 48/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.2838 - accuracy: 0.8917 - val_loss: 0.8168 - val_accuracy: 0.6250
# Epoch 49/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.2753 - accuracy: 0.8932 - val_loss: 0.8232 - val_accuracy: 0.6528
# Epoch 50/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.3037 - accuracy: 0.8763 - val_loss: 0.8455 - val_accuracy: 0.6944
# Epoch 51/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2804 - accuracy: 0.8790 - val_loss: 0.8594 - val_accuracy: 0.6389
# Epoch 52/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.3310 - accuracy: 0.8601 - val_loss: 0.8181 - val_accuracy: 0.6389
# Epoch 53/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.3132 - accuracy: 0.8791 - val_loss: 0.8316 - val_accuracy: 0.6806
# Epoch 54/100
# 10/10 [==============================] - 4s 388ms/step - loss: 0.2635 - accuracy: 0.9032 - val_loss: 0.8404 - val_accuracy: 0.6667
# Epoch 55/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.2788 - accuracy: 0.9085 - val_loss: 0.8295 - val_accuracy: 0.6250
# Epoch 56/100
# 10/10 [==============================] - 4s 358ms/step - loss: 0.2034 - accuracy: 0.9305 - val_loss: 0.7824 - val_accuracy: 0.6528
# Epoch 57/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.2773 - accuracy: 0.8992 - val_loss: 0.7460 - val_accuracy: 0.7083
# Epoch 58/100
# 10/10 [==============================] - 4s 358ms/step - loss: 0.2294 - accuracy: 0.9280 - val_loss: 0.7300 - val_accuracy: 0.6806
# Epoch 59/100
# 10/10 [==============================] - 4s 356ms/step - loss: 0.2880 - accuracy: 0.8958 - val_loss: 0.7902 - val_accuracy: 0.6944
# Epoch 60/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.2607 - accuracy: 0.8963 - val_loss: 0.8890 - val_accuracy: 0.6806
# Epoch 61/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.2585 - accuracy: 0.9027 - val_loss: 0.8458 - val_accuracy: 0.6250
# Epoch 62/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.2440 - accuracy: 0.9193 - val_loss: 0.7989 - val_accuracy: 0.6528
# Epoch 63/100
# 10/10 [==============================] - 3s 350ms/step - loss: 0.2707 - accuracy: 0.8935 - val_loss: 0.7834 - val_accuracy: 0.6667
# Epoch 64/100
# 10/10 [==============================] - 4s 344ms/step - loss: 0.2334 - accuracy: 0.9189 - val_loss: 0.8387 - val_accuracy: 0.5833
# Epoch 65/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.2602 - accuracy: 0.9060 - val_loss: 0.8862 - val_accuracy: 0.6111
# Epoch 66/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.2320 - accuracy: 0.9198 - val_loss: 0.8550 - val_accuracy: 0.6667
# Epoch 67/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.2029 - accuracy: 0.9244 - val_loss: 0.8740 - val_accuracy: 0.6667
# Epoch 68/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.1758 - accuracy: 0.9392 - val_loss: 0.9224 - val_accuracy: 0.6389
# Epoch 69/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.2026 - accuracy: 0.9225 - val_loss: 0.9394 - val_accuracy: 0.6528
# Epoch 70/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.2737 - accuracy: 0.9107 - val_loss: 1.0178 - val_accuracy: 0.6250
# Epoch 71/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.2097 - accuracy: 0.9236 - val_loss: 0.9182 - val_accuracy: 0.6667
# Epoch 72/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.1991 - accuracy: 0.9316 - val_loss: 0.8147 - val_accuracy: 0.7083
# Epoch 73/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.2189 - accuracy: 0.9113 - val_loss: 0.7845 - val_accuracy: 0.7222
# Epoch 74/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.2228 - accuracy: 0.9126 - val_loss: 0.7989 - val_accuracy: 0.7083
# Epoch 75/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.1677 - accuracy: 0.9369 - val_loss: 0.8310 - val_accuracy: 0.7500
# Epoch 76/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.2283 - accuracy: 0.9247 - val_loss: 0.8883 - val_accuracy: 0.6944
# Epoch 77/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.1713 - accuracy: 0.9454 - val_loss: 0.8334 - val_accuracy: 0.7083
# Epoch 78/100
# 10/10 [==============================] - 3s 327ms/step - loss: 0.1958 - accuracy: 0.9174 - val_loss: 0.7559 - val_accuracy: 0.7361
# Epoch 79/100
# 10/10 [==============================] - 3s 324ms/step - loss: 0.1669 - accuracy: 0.9325 - val_loss: 0.8021 - val_accuracy: 0.7222
# Epoch 80/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.1670 - accuracy: 0.9373 - val_loss: 0.8239 - val_accuracy: 0.7083
# Epoch 81/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1664 - accuracy: 0.9461 - val_loss: 0.8625 - val_accuracy: 0.7083
# Epoch 82/100
# 10/10 [==============================] - 3s 361ms/step - loss: 0.1717 - accuracy: 0.9505 - val_loss: 0.8998 - val_accuracy: 0.7083
# Epoch 83/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.1883 - accuracy: 0.9342 - val_loss: 0.8930 - val_accuracy: 0.7083
# Epoch 84/100
# 10/10 [==============================] - 4s 337ms/step - loss: 0.2231 - accuracy: 0.9242 - val_loss: 0.9076 - val_accuracy: 0.7083
# Epoch 85/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1673 - accuracy: 0.9308 - val_loss: 0.9072 - val_accuracy: 0.6944
# Epoch 86/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.2021 - accuracy: 0.9389 - val_loss: 0.8883 - val_accuracy: 0.7222
# Epoch 87/100
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1701 - accuracy: 0.9303 - val_loss: 0.8800 - val_accuracy: 0.7639
# Epoch 88/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1374 - accuracy: 0.9511 - val_loss: 0.8141 - val_accuracy: 0.7778
# Epoch 89/100
# 10/10 [==============================] - 4s 345ms/step - loss: 0.1886 - accuracy: 0.9448 - val_loss: 0.7516 - val_accuracy: 0.7639
# Epoch 90/100
# 10/10 [==============================] - 3s 353ms/step - loss: 0.2017 - accuracy: 0.9389 - val_loss: 0.7405 - val_accuracy: 0.7500
# Epoch 91/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.1747 - accuracy: 0.9281 - val_loss: 0.7792 - val_accuracy: 0.7500
# Epoch 92/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.1852 - accuracy: 0.9301 - val_loss: 0.7953 - val_accuracy: 0.7639
# Epoch 93/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.1750 - accuracy: 0.9529 - val_loss: 0.6574 - val_accuracy: 0.8056
# Epoch 94/100
# 10/10 [==============================] - 4s 339ms/step - loss: 0.1479 - accuracy: 0.9393 - val_loss: 0.6021 - val_accuracy: 0.7917
# Epoch 95/100
# 10/10 [==============================] - 3s 355ms/step - loss: 0.1969 - accuracy: 0.9408 - val_loss: 0.6343 - val_accuracy: 0.8333
# Epoch 96/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1344 - accuracy: 0.9601 - val_loss: 0.8094 - val_accuracy: 0.7778
# Epoch 97/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1352 - accuracy: 0.9445 - val_loss: 0.7978 - val_accuracy: 0.7917
# Epoch 98/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1441 - accuracy: 0.9478 - val_loss: 0.7496 - val_accuracy: 0.8056
# Epoch 99/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.1243 - accuracy: 0.9505 - val_loss: 0.7252 - val_accuracy: 0.7778
# Epoch 100/100
# 10/10 [==============================] - 3s 326ms/step - loss: 0.1062 - accuracy: 0.9558 - val_loss: 0.7466 - val_accuracy: 0.7778

# %%
#for model3
t_model3.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history3 = t_model3.fit(train_dataset,shuffle=True,validation_data=valid_dataset,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 24s 721ms/step - loss: 1.7279 - accuracy: 0.2582 - val_loss: 1.6058 - val_accuracy: 0.2222
# Epoch 2/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.4593 - accuracy: 0.3385 - val_loss: 1.6257 - val_accuracy: 0.2083
# Epoch 3/100
# 10/10 [==============================] - 4s 375ms/step - loss: 1.3295 - accuracy: 0.4171 - val_loss: 1.5861 - val_accuracy: 0.1944
# Epoch 4/100
# 10/10 [==============================] - 4s 337ms/step - loss: 1.2943 - accuracy: 0.4744 - val_loss: 1.6350 - val_accuracy: 0.2083
# Epoch 5/100
# 10/10 [==============================] - 3s 337ms/step - loss: 1.1476 - accuracy: 0.4945 - val_loss: 1.5461 - val_accuracy: 0.3194
# Epoch 6/100
# 10/10 [==============================] - 4s 345ms/step - loss: 1.1933 - accuracy: 0.4976 - val_loss: 1.5721 - val_accuracy: 0.2778
# Epoch 7/100
# 10/10 [==============================] - 4s 360ms/step - loss: 1.1136 - accuracy: 0.5340 - val_loss: 1.6189 - val_accuracy: 0.2778
# Epoch 8/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9794 - accuracy: 0.5944 - val_loss: 1.5615 - val_accuracy: 0.2639
# Epoch 9/100
# 10/10 [==============================] - 4s 346ms/step - loss: 1.0193 - accuracy: 0.5234 - val_loss: 1.5552 - val_accuracy: 0.2639
# Epoch 10/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.9500 - accuracy: 0.6142 - val_loss: 1.5506 - val_accuracy: 0.2361
# Epoch 11/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9143 - accuracy: 0.5863 - val_loss: 1.5253 - val_accuracy: 0.2500
# Epoch 12/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.8269 - accuracy: 0.6416 - val_loss: 1.4928 - val_accuracy: 0.2639
# Epoch 13/100
# 10/10 [==============================] - 4s 358ms/step - loss: 0.8874 - accuracy: 0.6021 - val_loss: 1.5046 - val_accuracy: 0.2917
# Epoch 14/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.7733 - accuracy: 0.6757 - val_loss: 1.5163 - val_accuracy: 0.2917
# Epoch 15/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.7875 - accuracy: 0.6692 - val_loss: 1.5116 - val_accuracy: 0.2917
# Epoch 16/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.8439 - accuracy: 0.6023 - val_loss: 1.5237 - val_accuracy: 0.2917
# Epoch 17/100
# 10/10 [==============================] - 4s 373ms/step - loss: 0.8222 - accuracy: 0.6605 - val_loss: 1.5459 - val_accuracy: 0.2917
# Epoch 18/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.7478 - accuracy: 0.6750 - val_loss: 1.5985 - val_accuracy: 0.2917
# Epoch 19/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.7184 - accuracy: 0.7171 - val_loss: 1.7018 - val_accuracy: 0.2639
# Epoch 20/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.7023 - accuracy: 0.7144 - val_loss: 1.7466 - val_accuracy: 0.2778
# Epoch 21/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.7047 - accuracy: 0.6963 - val_loss: 1.7676 - val_accuracy: 0.3056
# Epoch 22/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.6984 - accuracy: 0.6870 - val_loss: 1.7330 - val_accuracy: 0.3194
# Epoch 23/100
# 10/10 [==============================] - 4s 371ms/step - loss: 0.6539 - accuracy: 0.7266 - val_loss: 1.6945 - val_accuracy: 0.3333
# Epoch 24/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.6259 - accuracy: 0.7430 - val_loss: 1.6993 - val_accuracy: 0.3333
# Epoch 25/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.6645 - accuracy: 0.7032 - val_loss: 1.6325 - val_accuracy: 0.3611
# Epoch 26/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.6043 - accuracy: 0.7524 - val_loss: 1.5768 - val_accuracy: 0.3611
# Epoch 27/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.6033 - accuracy: 0.7564 - val_loss: 1.5442 - val_accuracy: 0.3889
# Epoch 28/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.5908 - accuracy: 0.7545 - val_loss: 1.4599 - val_accuracy: 0.4028
# Epoch 29/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.6652 - accuracy: 0.7629 - val_loss: 1.3641 - val_accuracy: 0.4167
# Epoch 30/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.5081 - accuracy: 0.7855 - val_loss: 1.3872 - val_accuracy: 0.4167
# Epoch 31/100
# 10/10 [==============================] - 4s 344ms/step - loss: 0.5623 - accuracy: 0.7380 - val_loss: 1.5105 - val_accuracy: 0.4028
# Epoch 32/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.5103 - accuracy: 0.7798 - val_loss: 1.4024 - val_accuracy: 0.4306
# Epoch 33/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.5115 - accuracy: 0.7818 - val_loss: 1.3357 - val_accuracy: 0.4444
# Epoch 34/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.4934 - accuracy: 0.7929 - val_loss: 1.3103 - val_accuracy: 0.4583
# Epoch 35/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.4841 - accuracy: 0.7945 - val_loss: 1.2170 - val_accuracy: 0.4583
# Epoch 36/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.5434 - accuracy: 0.7690 - val_loss: 1.2111 - val_accuracy: 0.4722
# Epoch 37/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.5137 - accuracy: 0.7846 - val_loss: 1.1793 - val_accuracy: 0.5278
# Epoch 38/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.5016 - accuracy: 0.8040 - val_loss: 1.1685 - val_accuracy: 0.5278
# Epoch 39/100
# 10/10 [==============================] - 4s 344ms/step - loss: 0.4711 - accuracy: 0.8158 - val_loss: 1.1483 - val_accuracy: 0.5417
# Epoch 40/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.4435 - accuracy: 0.8388 - val_loss: 1.1440 - val_accuracy: 0.5000
# Epoch 41/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.4907 - accuracy: 0.7924 - val_loss: 1.1594 - val_accuracy: 0.4722
# Epoch 42/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.4506 - accuracy: 0.8295 - val_loss: 1.1356 - val_accuracy: 0.4722
# Epoch 43/100
# 10/10 [==============================] - 4s 347ms/step - loss: 0.4039 - accuracy: 0.8327 - val_loss: 1.1240 - val_accuracy: 0.4861
# Epoch 44/100
# 10/10 [==============================] - 4s 413ms/step - loss: 0.4559 - accuracy: 0.8224 - val_loss: 1.1300 - val_accuracy: 0.5139
# Epoch 45/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.3874 - accuracy: 0.8464 - val_loss: 1.0908 - val_accuracy: 0.5694
# Epoch 46/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.4143 - accuracy: 0.8419 - val_loss: 1.0737 - val_accuracy: 0.5278
# Epoch 47/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.3908 - accuracy: 0.8539 - val_loss: 1.1087 - val_accuracy: 0.5000
# Epoch 48/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.4198 - accuracy: 0.8399 - val_loss: 1.1346 - val_accuracy: 0.5000
# Epoch 49/100
# 10/10 [==============================] - 4s 344ms/step - loss: 0.3676 - accuracy: 0.8593 - val_loss: 1.1696 - val_accuracy: 0.5000
# Epoch 50/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.3376 - accuracy: 0.8652 - val_loss: 1.1404 - val_accuracy: 0.5556
# Epoch 51/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.3968 - accuracy: 0.8476 - val_loss: 1.1060 - val_accuracy: 0.6250
# Epoch 52/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.3059 - accuracy: 0.8781 - val_loss: 1.0496 - val_accuracy: 0.6111
# Epoch 53/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.3421 - accuracy: 0.8684 - val_loss: 1.0144 - val_accuracy: 0.6250
# Epoch 54/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.2995 - accuracy: 0.8796 - val_loss: 1.0355 - val_accuracy: 0.6250
# Epoch 55/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.3474 - accuracy: 0.8757 - val_loss: 1.0598 - val_accuracy: 0.6111
# Epoch 56/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.3077 - accuracy: 0.8716 - val_loss: 1.1289 - val_accuracy: 0.5833
# Epoch 57/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2751 - accuracy: 0.8863 - val_loss: 1.1515 - val_accuracy: 0.5694
# Epoch 58/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.3292 - accuracy: 0.8868 - val_loss: 1.1673 - val_accuracy: 0.6250
# Epoch 59/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.3131 - accuracy: 0.8820 - val_loss: 1.1341 - val_accuracy: 0.5972
# Epoch 60/100
# 10/10 [==============================] - 4s 347ms/step - loss: 0.2548 - accuracy: 0.9003 - val_loss: 0.9834 - val_accuracy: 0.6806
# Epoch 61/100
# 10/10 [==============================] - 4s 372ms/step - loss: 0.3244 - accuracy: 0.8750 - val_loss: 0.8514 - val_accuracy: 0.6667
# Epoch 62/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.2730 - accuracy: 0.8968 - val_loss: 0.7828 - val_accuracy: 0.6944
# Epoch 63/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2491 - accuracy: 0.9076 - val_loss: 0.8380 - val_accuracy: 0.6806
# Epoch 64/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.2606 - accuracy: 0.8809 - val_loss: 0.8333 - val_accuracy: 0.6667
# Epoch 65/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.2598 - accuracy: 0.8987 - val_loss: 0.9095 - val_accuracy: 0.6667
# Epoch 66/100
# 10/10 [==============================] - 4s 347ms/step - loss: 0.2990 - accuracy: 0.8835 - val_loss: 1.0047 - val_accuracy: 0.7083
# Epoch 67/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.2738 - accuracy: 0.8970 - val_loss: 0.9395 - val_accuracy: 0.7083
# Epoch 68/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.2633 - accuracy: 0.9129 - val_loss: 0.9412 - val_accuracy: 0.7222
# Epoch 69/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.2457 - accuracy: 0.9006 - val_loss: 0.9306 - val_accuracy: 0.7361
# Epoch 70/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.2181 - accuracy: 0.9210 - val_loss: 0.7579 - val_accuracy: 0.7500
# Epoch 71/100
# 10/10 [==============================] - 4s 342ms/step - loss: 0.2558 - accuracy: 0.9147 - val_loss: 0.7445 - val_accuracy: 0.7222
# Epoch 72/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.2197 - accuracy: 0.9047 - val_loss: 0.7052 - val_accuracy: 0.7917
# Epoch 73/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.2180 - accuracy: 0.9171 - val_loss: 0.7893 - val_accuracy: 0.7917
# Epoch 74/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.2307 - accuracy: 0.9187 - val_loss: 0.8083 - val_accuracy: 0.7639
# Epoch 75/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.2232 - accuracy: 0.9238 - val_loss: 0.8354 - val_accuracy: 0.7361
# Epoch 76/100
# 10/10 [==============================] - 4s 345ms/step - loss: 0.2435 - accuracy: 0.9006 - val_loss: 0.8627 - val_accuracy: 0.7639
# Epoch 77/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.1743 - accuracy: 0.9260 - val_loss: 0.8919 - val_accuracy: 0.7639
# Epoch 78/100
# 10/10 [==============================] - 4s 348ms/step - loss: 0.2335 - accuracy: 0.9258 - val_loss: 0.7869 - val_accuracy: 0.7500
# Epoch 79/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.2060 - accuracy: 0.9125 - val_loss: 0.7354 - val_accuracy: 0.7500
# Epoch 80/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.2878 - accuracy: 0.9098 - val_loss: 0.7817 - val_accuracy: 0.7361
# Epoch 81/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.2853 - accuracy: 0.8929 - val_loss: 0.8520 - val_accuracy: 0.7222
# Epoch 82/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.2332 - accuracy: 0.9114 - val_loss: 0.7742 - val_accuracy: 0.7917
# Epoch 83/100
# 10/10 [==============================] - 4s 356ms/step - loss: 0.1734 - accuracy: 0.9209 - val_loss: 0.7807 - val_accuracy: 0.7778
# Epoch 84/100
# 10/10 [==============================] - 4s 345ms/step - loss: 0.1800 - accuracy: 0.9367 - val_loss: 0.8363 - val_accuracy: 0.7361
# Epoch 85/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2256 - accuracy: 0.9259 - val_loss: 0.8832 - val_accuracy: 0.7639
# Epoch 86/100
# 10/10 [==============================] - 4s 382ms/step - loss: 0.1747 - accuracy: 0.9333 - val_loss: 0.8827 - val_accuracy: 0.7778
# Epoch 87/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.1410 - accuracy: 0.9504 - val_loss: 0.7613 - val_accuracy: 0.6944
# Epoch 88/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.1767 - accuracy: 0.9366 - val_loss: 0.7883 - val_accuracy: 0.6944
# Epoch 89/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.1740 - accuracy: 0.9337 - val_loss: 0.8040 - val_accuracy: 0.7361
# Epoch 90/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1544 - accuracy: 0.9456 - val_loss: 0.6948 - val_accuracy: 0.7778
# Epoch 91/100
# 10/10 [==============================] - 4s 345ms/step - loss: 0.1510 - accuracy: 0.9537 - val_loss: 0.7324 - val_accuracy: 0.7917
# Epoch 92/100
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1546 - accuracy: 0.9497 - val_loss: 0.6875 - val_accuracy: 0.7917
# Epoch 93/100
# 10/10 [==============================] - 3s 360ms/step - loss: 0.1895 - accuracy: 0.9295 - val_loss: 0.8914 - val_accuracy: 0.8194
# Epoch 94/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.1672 - accuracy: 0.9328 - val_loss: 0.8380 - val_accuracy: 0.7917
# Epoch 95/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.1572 - accuracy: 0.9393 - val_loss: 0.9504 - val_accuracy: 0.7500
# Epoch 96/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.1815 - accuracy: 0.9345 - val_loss: 0.8487 - val_accuracy: 0.8056
# Epoch 97/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1481 - accuracy: 0.9573 - val_loss: 0.8243 - val_accuracy: 0.8194
# Epoch 98/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.1930 - accuracy: 0.9327 - val_loss: 0.7191 - val_accuracy: 0.8333
# Epoch 99/100
# 10/10 [==============================] - 4s 345ms/step - loss: 0.1446 - accuracy: 0.9666 - val_loss: 0.7225 - val_accuracy: 0.8056
# Epoch 100/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.1693 - accuracy: 0.9418 - val_loss: 0.7473 - val_accuracy: 0.8056

# %%
#for model3
t_model4.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history4= t_model4.fit(train_dataset,shuffle=True,validation_data=valid_dataset,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 16s 712ms/step - loss: 2.0196 - accuracy: 0.2625 - val_loss: 1.6362 - val_accuracy: 0.2500
# Epoch 2/100
# 10/10 [==============================] - 3s 347ms/step - loss: 1.8594 - accuracy: 0.2419 - val_loss: 1.5925 - val_accuracy: 0.2500
# Epoch 3/100
# 10/10 [==============================] - 3s 344ms/step - loss: 1.6346 - accuracy: 0.2727 - val_loss: 1.5317 - val_accuracy: 0.2917
# Epoch 4/100
# 10/10 [==============================] - 3s 356ms/step - loss: 1.4469 - accuracy: 0.3265 - val_loss: 1.4802 - val_accuracy: 0.3194
# Epoch 5/100
# 10/10 [==============================] - 3s 347ms/step - loss: 1.5023 - accuracy: 0.2835 - val_loss: 1.4420 - val_accuracy: 0.2778
# Epoch 6/100
# 10/10 [==============================] - 4s 353ms/step - loss: 1.4172 - accuracy: 0.3741 - val_loss: 1.4182 - val_accuracy: 0.3056
# Epoch 7/100
# 10/10 [==============================] - 3s 349ms/step - loss: 1.3273 - accuracy: 0.3758 - val_loss: 1.3976 - val_accuracy: 0.3194
# Epoch 8/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.2758 - accuracy: 0.4211 - val_loss: 1.3818 - val_accuracy: 0.3472
# Epoch 9/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.2877 - accuracy: 0.3921 - val_loss: 1.3590 - val_accuracy: 0.3056
# Epoch 10/100
# 10/10 [==============================] - 3s 326ms/step - loss: 1.3294 - accuracy: 0.3804 - val_loss: 1.3453 - val_accuracy: 0.3750
# Epoch 11/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.2329 - accuracy: 0.4070 - val_loss: 1.3297 - val_accuracy: 0.3889
# Epoch 12/100
# 10/10 [==============================] - 3s 324ms/step - loss: 1.2708 - accuracy: 0.4073 - val_loss: 1.3123 - val_accuracy: 0.3750
# Epoch 13/100
# 10/10 [==============================] - 3s 321ms/step - loss: 1.2914 - accuracy: 0.4044 - val_loss: 1.2979 - val_accuracy: 0.3611
# Epoch 14/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.2241 - accuracy: 0.4470 - val_loss: 1.2866 - val_accuracy: 0.3333
# Epoch 15/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.2654 - accuracy: 0.4223 - val_loss: 1.2737 - val_accuracy: 0.3472
# Epoch 16/100
# 10/10 [==============================] - 3s 324ms/step - loss: 1.1982 - accuracy: 0.4259 - val_loss: 1.2649 - val_accuracy: 0.3750
# Epoch 17/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.2032 - accuracy: 0.4177 - val_loss: 1.2483 - val_accuracy: 0.3611
# Epoch 18/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.2147 - accuracy: 0.4131 - val_loss: 1.2364 - val_accuracy: 0.3472
# Epoch 19/100
# 10/10 [==============================] - 4s 348ms/step - loss: 1.1980 - accuracy: 0.4314 - val_loss: 1.2232 - val_accuracy: 0.3750
# Epoch 20/100
# 10/10 [==============================] - 4s 368ms/step - loss: 1.1759 - accuracy: 0.4186 - val_loss: 1.2141 - val_accuracy: 0.4028
# Epoch 21/100
# 10/10 [==============================] - 3s 351ms/step - loss: 1.1621 - accuracy: 0.4808 - val_loss: 1.2101 - val_accuracy: 0.4028
# Epoch 22/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.1753 - accuracy: 0.4689 - val_loss: 1.2054 - val_accuracy: 0.4028
# Epoch 23/100
# 10/10 [==============================] - 3s 344ms/step - loss: 1.1720 - accuracy: 0.4936 - val_loss: 1.2036 - val_accuracy: 0.4167
# Epoch 24/100
# 10/10 [==============================] - 4s 361ms/step - loss: 1.1633 - accuracy: 0.4761 - val_loss: 1.1966 - val_accuracy: 0.4028
# Epoch 25/100
# 10/10 [==============================] - 4s 362ms/step - loss: 1.1842 - accuracy: 0.4310 - val_loss: 1.1845 - val_accuracy: 0.4028
# Epoch 26/100
# 10/10 [==============================] - 4s 357ms/step - loss: 1.1492 - accuracy: 0.4939 - val_loss: 1.1813 - val_accuracy: 0.4028
# Epoch 27/100
# 10/10 [==============================] - 3s 339ms/step - loss: 1.1340 - accuracy: 0.4646 - val_loss: 1.1740 - val_accuracy: 0.3750
# Epoch 28/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.1952 - accuracy: 0.4564 - val_loss: 1.1656 - val_accuracy: 0.4167
# Epoch 29/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.1401 - accuracy: 0.4906 - val_loss: 1.1672 - val_accuracy: 0.3889
# Epoch 30/100
# 10/10 [==============================] - 4s 347ms/step - loss: 1.1478 - accuracy: 0.4483 - val_loss: 1.1716 - val_accuracy: 0.3889
# Epoch 31/100
# 10/10 [==============================] - 4s 353ms/step - loss: 1.0938 - accuracy: 0.5164 - val_loss: 1.1684 - val_accuracy: 0.3889
# Epoch 32/100
# 10/10 [==============================] - 3s 336ms/step - loss: 1.1681 - accuracy: 0.4685 - val_loss: 1.1682 - val_accuracy: 0.4028
# Epoch 33/100
# 10/10 [==============================] - 3s 344ms/step - loss: 1.1094 - accuracy: 0.5094 - val_loss: 1.1550 - val_accuracy: 0.4167
# Epoch 34/100
# 10/10 [==============================] - 3s 339ms/step - loss: 1.0700 - accuracy: 0.5254 - val_loss: 1.1519 - val_accuracy: 0.4306
# Epoch 35/100
# 10/10 [==============================] - 3s 339ms/step - loss: 1.1199 - accuracy: 0.4928 - val_loss: 1.1589 - val_accuracy: 0.4167
# Epoch 36/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.0814 - accuracy: 0.5160 - val_loss: 1.1615 - val_accuracy: 0.4306
# Epoch 37/100
# 10/10 [==============================] - 4s 366ms/step - loss: 1.0926 - accuracy: 0.5076 - val_loss: 1.1620 - val_accuracy: 0.4167
# Epoch 38/100
# 10/10 [==============================] - 4s 360ms/step - loss: 1.1124 - accuracy: 0.5078 - val_loss: 1.1667 - val_accuracy: 0.4306
# Epoch 39/100
# 10/10 [==============================] - 4s 360ms/step - loss: 1.1100 - accuracy: 0.5152 - val_loss: 1.1612 - val_accuracy: 0.4444
# Epoch 40/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.0854 - accuracy: 0.5044 - val_loss: 1.1538 - val_accuracy: 0.4306
# Epoch 41/100
# 10/10 [==============================] - 3s 357ms/step - loss: 1.1354 - accuracy: 0.4753 - val_loss: 1.1477 - val_accuracy: 0.4306
# Epoch 42/100
# 10/10 [==============================] - 4s 389ms/step - loss: 1.0864 - accuracy: 0.4990 - val_loss: 1.1459 - val_accuracy: 0.4306
# Epoch 43/100
# 10/10 [==============================] - 3s 355ms/step - loss: 1.1166 - accuracy: 0.4896 - val_loss: 1.1366 - val_accuracy: 0.4028
# Epoch 44/100
# 10/10 [==============================] - 3s 350ms/step - loss: 1.0448 - accuracy: 0.5276 - val_loss: 1.1339 - val_accuracy: 0.4028
# Epoch 45/100
# 10/10 [==============================] - 3s 337ms/step - loss: 1.1078 - accuracy: 0.5100 - val_loss: 1.1196 - val_accuracy: 0.4167
# Epoch 46/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.0453 - accuracy: 0.5086 - val_loss: 1.1109 - val_accuracy: 0.4167
# Epoch 47/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.0469 - accuracy: 0.5137 - val_loss: 1.1161 - val_accuracy: 0.4306
# Epoch 48/100
# 10/10 [==============================] - 3s 349ms/step - loss: 1.0575 - accuracy: 0.5098 - val_loss: 1.1228 - val_accuracy: 0.4167
# Epoch 49/100
# 10/10 [==============================] - 4s 371ms/step - loss: 1.0230 - accuracy: 0.5520 - val_loss: 1.1307 - val_accuracy: 0.4167
# Epoch 50/100
# 10/10 [==============================] - 4s 369ms/step - loss: 1.0718 - accuracy: 0.4999 - val_loss: 1.1398 - val_accuracy: 0.4444
# Epoch 51/100
# 10/10 [==============================] - 4s 347ms/step - loss: 1.0277 - accuracy: 0.5223 - val_loss: 1.1378 - val_accuracy: 0.4167
# Epoch 52/100
# 10/10 [==============================] - 3s 347ms/step - loss: 1.0962 - accuracy: 0.5095 - val_loss: 1.1268 - val_accuracy: 0.4444
# Epoch 53/100
# 10/10 [==============================] - 4s 357ms/step - loss: 1.0629 - accuracy: 0.5317 - val_loss: 1.1210 - val_accuracy: 0.4444
# Epoch 54/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.0764 - accuracy: 0.4903 - val_loss: 1.1147 - val_accuracy: 0.4444
# Epoch 55/100
# 10/10 [==============================] - 4s 424ms/step - loss: 1.0689 - accuracy: 0.4757 - val_loss: 1.1284 - val_accuracy: 0.3889
# Epoch 56/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.9873 - accuracy: 0.5813 - val_loss: 1.1322 - val_accuracy: 0.4028
# Epoch 57/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.9973 - accuracy: 0.5579 - val_loss: 1.1268 - val_accuracy: 0.4167
# Epoch 58/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.0239 - accuracy: 0.5437 - val_loss: 1.1280 - val_accuracy: 0.3889
# Epoch 59/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.0701 - accuracy: 0.5091 - val_loss: 1.1313 - val_accuracy: 0.4028
# Epoch 60/100
# 10/10 [==============================] - 3s 338ms/step - loss: 1.0278 - accuracy: 0.5362 - val_loss: 1.1345 - val_accuracy: 0.4167
# Epoch 61/100
# 10/10 [==============================] - 4s 369ms/step - loss: 1.0175 - accuracy: 0.5501 - val_loss: 1.1324 - val_accuracy: 0.4167
# Epoch 62/100
# 10/10 [==============================] - 3s 350ms/step - loss: 1.0306 - accuracy: 0.5289 - val_loss: 1.1243 - val_accuracy: 0.4028
# Epoch 63/100
# 10/10 [==============================] - 4s 361ms/step - loss: 1.0180 - accuracy: 0.5167 - val_loss: 1.1296 - val_accuracy: 0.4167
# Epoch 64/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9729 - accuracy: 0.5495 - val_loss: 1.1382 - val_accuracy: 0.4306
# Epoch 65/100
# 10/10 [==============================] - 4s 343ms/step - loss: 0.9701 - accuracy: 0.5361 - val_loss: 1.1311 - val_accuracy: 0.4167
# Epoch 66/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9575 - accuracy: 0.5878 - val_loss: 1.1241 - val_accuracy: 0.4167
# Epoch 67/100
# 10/10 [==============================] - 3s 347ms/step - loss: 1.0256 - accuracy: 0.5356 - val_loss: 1.1195 - val_accuracy: 0.4167
# Epoch 68/100
# 10/10 [==============================] - 3s 351ms/step - loss: 0.9994 - accuracy: 0.5518 - val_loss: 1.1201 - val_accuracy: 0.4306
# Epoch 69/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9529 - accuracy: 0.5788 - val_loss: 1.1178 - val_accuracy: 0.4167
# Epoch 70/100
# 10/10 [==============================] - 3s 356ms/step - loss: 0.9680 - accuracy: 0.5716 - val_loss: 1.1214 - val_accuracy: 0.4167
# Epoch 71/100
# 10/10 [==============================] - 3s 356ms/step - loss: 0.9656 - accuracy: 0.5617 - val_loss: 1.1123 - val_accuracy: 0.4444
# Epoch 72/100
# 10/10 [==============================] - 4s 358ms/step - loss: 0.9317 - accuracy: 0.6020 - val_loss: 1.1125 - val_accuracy: 0.4444
# Epoch 73/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.0104 - accuracy: 0.5662 - val_loss: 1.1114 - val_accuracy: 0.4306
# Epoch 74/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.9759 - accuracy: 0.5691 - val_loss: 1.0933 - val_accuracy: 0.4306
# Epoch 75/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.9813 - accuracy: 0.5652 - val_loss: 1.0951 - val_accuracy: 0.4583
# Epoch 76/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.9298 - accuracy: 0.6091 - val_loss: 1.0849 - val_accuracy: 0.4444
# Epoch 77/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.9811 - accuracy: 0.5692 - val_loss: 1.0862 - val_accuracy: 0.4306
# Epoch 78/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.0040 - accuracy: 0.5382 - val_loss: 1.0997 - val_accuracy: 0.4306
# Epoch 79/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.9283 - accuracy: 0.5894 - val_loss: 1.1060 - val_accuracy: 0.4306
# Epoch 80/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9455 - accuracy: 0.5749 - val_loss: 1.0972 - val_accuracy: 0.4444
# Epoch 81/100
# 10/10 [==============================] - 3s 353ms/step - loss: 0.9363 - accuracy: 0.5816 - val_loss: 1.0831 - val_accuracy: 0.4861
# Epoch 82/100
# 10/10 [==============================] - 4s 371ms/step - loss: 0.9307 - accuracy: 0.5662 - val_loss: 1.0773 - val_accuracy: 0.5000
# Epoch 83/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.8881 - accuracy: 0.6390 - val_loss: 1.0859 - val_accuracy: 0.4306
# Epoch 84/100
# 10/10 [==============================] - 4s 347ms/step - loss: 0.9120 - accuracy: 0.6216 - val_loss: 1.0815 - val_accuracy: 0.4306
# Epoch 85/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9166 - accuracy: 0.5757 - val_loss: 1.0834 - val_accuracy: 0.4306
# Epoch 86/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.9706 - accuracy: 0.5891 - val_loss: 1.0775 - val_accuracy: 0.4306
# Epoch 87/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.9902 - accuracy: 0.5424 - val_loss: 1.0790 - val_accuracy: 0.4444
# Epoch 88/100
# 10/10 [==============================] - 4s 351ms/step - loss: 1.0342 - accuracy: 0.5290 - val_loss: 1.0812 - val_accuracy: 0.4306
# Epoch 89/100
# 10/10 [==============================] - 3s 363ms/step - loss: 0.9670 - accuracy: 0.5372 - val_loss: 1.0837 - val_accuracy: 0.4444
# Epoch 90/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.9016 - accuracy: 0.6086 - val_loss: 1.0855 - val_accuracy: 0.4583
# Epoch 91/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.9575 - accuracy: 0.5762 - val_loss: 1.0849 - val_accuracy: 0.4444
# Epoch 92/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.9285 - accuracy: 0.5851 - val_loss: 1.0792 - val_accuracy: 0.4167
# Epoch 93/100
# 10/10 [==============================] - 4s 349ms/step - loss: 0.9268 - accuracy: 0.5749 - val_loss: 1.0785 - val_accuracy: 0.4722
# Epoch 94/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.9407 - accuracy: 0.5949 - val_loss: 1.0898 - val_accuracy: 0.4722
# Epoch 95/100
# 10/10 [==============================] - 3s 363ms/step - loss: 0.8726 - accuracy: 0.6267 - val_loss: 1.0959 - val_accuracy: 0.4722
# Epoch 96/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.9629 - accuracy: 0.5724 - val_loss: 1.0874 - val_accuracy: 0.4861
# Epoch 97/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.0045 - accuracy: 0.5628 - val_loss: 1.0869 - val_accuracy: 0.5000
# Epoch 98/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9375 - accuracy: 0.5938 - val_loss: 1.0899 - val_accuracy: 0.4722
# Epoch 99/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.9548 - accuracy: 0.5742 - val_loss: 1.0843 - val_accuracy: 0.4444
# Epoch 100/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.9498 - accuracy: 0.5657 - val_loss: 1.0755 - val_accuracy: 0.4861

# %%
#for model3
t_model5.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history5 = t_model5.fit(train_dataset,shuffle=True,validation_data=valid_dataset,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 15s 672ms/step - loss: 1.9810 - accuracy: 0.2251 - val_loss: 1.5379 - val_accuracy: 0.2639
# Epoch 2/100
# 10/10 [==============================] - 3s 333ms/step - loss: 1.6861 - accuracy: 0.2719 - val_loss: 1.4302 - val_accuracy: 0.3056
# Epoch 3/100
# 10/10 [==============================] - 3s 328ms/step - loss: 1.5791 - accuracy: 0.2892 - val_loss: 1.3889 - val_accuracy: 0.2917
# Epoch 4/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.4242 - accuracy: 0.3477 - val_loss: 1.3559 - val_accuracy: 0.3611
# Epoch 5/100
# 10/10 [==============================] - 3s 330ms/step - loss: 1.3878 - accuracy: 0.3444 - val_loss: 1.3329 - val_accuracy: 0.3611
# Epoch 6/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.3471 - accuracy: 0.3543 - val_loss: 1.3109 - val_accuracy: 0.3750
# Epoch 7/100
# 10/10 [==============================] - 3s 322ms/step - loss: 1.3441 - accuracy: 0.3752 - val_loss: 1.2967 - val_accuracy: 0.4028
# Epoch 8/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.3847 - accuracy: 0.3691 - val_loss: 1.2809 - val_accuracy: 0.4444
# Epoch 9/100
# 10/10 [==============================] - 4s 361ms/step - loss: 1.2749 - accuracy: 0.4217 - val_loss: 1.2676 - val_accuracy: 0.4722
# Epoch 10/100
# 10/10 [==============================] - 3s 348ms/step - loss: 1.3190 - accuracy: 0.4076 - val_loss: 1.2548 - val_accuracy: 0.5000
# Epoch 11/100
# 10/10 [==============================] - 4s 350ms/step - loss: 1.2656 - accuracy: 0.4114 - val_loss: 1.2468 - val_accuracy: 0.5139
# Epoch 12/100
# 10/10 [==============================] - 4s 347ms/step - loss: 1.2706 - accuracy: 0.4128 - val_loss: 1.2385 - val_accuracy: 0.5139
# Epoch 13/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.2340 - accuracy: 0.4501 - val_loss: 1.2336 - val_accuracy: 0.4722
# Epoch 14/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.2268 - accuracy: 0.4500 - val_loss: 1.2302 - val_accuracy: 0.4583
# Epoch 15/100
# 10/10 [==============================] - 4s 361ms/step - loss: 1.1996 - accuracy: 0.4159 - val_loss: 1.2227 - val_accuracy: 0.4167
# Epoch 16/100
# 10/10 [==============================] - 3s 348ms/step - loss: 1.2157 - accuracy: 0.4346 - val_loss: 1.2148 - val_accuracy: 0.4306
# Epoch 17/100
# 10/10 [==============================] - 4s 357ms/step - loss: 1.2091 - accuracy: 0.4425 - val_loss: 1.2051 - val_accuracy: 0.4306
# Epoch 18/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.1648 - accuracy: 0.4450 - val_loss: 1.1969 - val_accuracy: 0.4167
# Epoch 19/100
# 10/10 [==============================] - 3s 353ms/step - loss: 1.1914 - accuracy: 0.4825 - val_loss: 1.1823 - val_accuracy: 0.4306
# Epoch 20/100
# 10/10 [==============================] - 3s 346ms/step - loss: 1.1779 - accuracy: 0.4557 - val_loss: 1.1732 - val_accuracy: 0.4306
# Epoch 21/100
# 10/10 [==============================] - 3s 354ms/step - loss: 1.1198 - accuracy: 0.4744 - val_loss: 1.1610 - val_accuracy: 0.4306
# Epoch 22/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.1505 - accuracy: 0.4952 - val_loss: 1.1476 - val_accuracy: 0.4167
# Epoch 23/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.0935 - accuracy: 0.5306 - val_loss: 1.1372 - val_accuracy: 0.4583
# Epoch 24/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.0871 - accuracy: 0.5337 - val_loss: 1.1371 - val_accuracy: 0.4583
# Epoch 25/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.1119 - accuracy: 0.4794 - val_loss: 1.1369 - val_accuracy: 0.4167
# Epoch 26/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.1003 - accuracy: 0.5111 - val_loss: 1.1330 - val_accuracy: 0.4167
# Epoch 27/100
# 10/10 [==============================] - 3s 338ms/step - loss: 1.1132 - accuracy: 0.5040 - val_loss: 1.1257 - val_accuracy: 0.4167
# Epoch 28/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.1130 - accuracy: 0.5069 - val_loss: 1.1170 - val_accuracy: 0.4028
# Epoch 29/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0569 - accuracy: 0.5454 - val_loss: 1.1054 - val_accuracy: 0.4167
# Epoch 30/100
# 10/10 [==============================] - 3s 346ms/step - loss: 1.1317 - accuracy: 0.4843 - val_loss: 1.1034 - val_accuracy: 0.4167
# Epoch 31/100
# 10/10 [==============================] - 3s 352ms/step - loss: 1.0852 - accuracy: 0.5061 - val_loss: 1.1085 - val_accuracy: 0.4306
# Epoch 32/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.0868 - accuracy: 0.4868 - val_loss: 1.0965 - val_accuracy: 0.4167
# Epoch 33/100
# 10/10 [==============================] - 3s 353ms/step - loss: 1.0840 - accuracy: 0.4841 - val_loss: 1.0917 - val_accuracy: 0.4306
# Epoch 34/100
# 10/10 [==============================] - 4s 354ms/step - loss: 1.0892 - accuracy: 0.5122 - val_loss: 1.0935 - val_accuracy: 0.4306
# Epoch 35/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0263 - accuracy: 0.5445 - val_loss: 1.0872 - val_accuracy: 0.4167
# Epoch 36/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.0965 - accuracy: 0.5197 - val_loss: 1.0922 - val_accuracy: 0.4306
# Epoch 37/100
# 10/10 [==============================] - 3s 352ms/step - loss: 0.9906 - accuracy: 0.5907 - val_loss: 1.0805 - val_accuracy: 0.4167
# Epoch 38/100
# 10/10 [==============================] - 3s 359ms/step - loss: 1.0327 - accuracy: 0.5409 - val_loss: 1.0752 - val_accuracy: 0.4028
# Epoch 39/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.0228 - accuracy: 0.5408 - val_loss: 1.0745 - val_accuracy: 0.4167
# Epoch 40/100
# 10/10 [==============================] - 3s 337ms/step - loss: 1.0263 - accuracy: 0.5352 - val_loss: 1.0739 - val_accuracy: 0.4167
# Epoch 41/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.0936 - accuracy: 0.4887 - val_loss: 1.0625 - val_accuracy: 0.4167
# Epoch 42/100
# 10/10 [==============================] - 3s 348ms/step - loss: 1.0594 - accuracy: 0.5530 - val_loss: 1.0549 - val_accuracy: 0.4444
# Epoch 43/100
# 10/10 [==============================] - 4s 363ms/step - loss: 1.0335 - accuracy: 0.5087 - val_loss: 1.0599 - val_accuracy: 0.4167
# Epoch 44/100
# 10/10 [==============================] - 4s 345ms/step - loss: 1.0721 - accuracy: 0.4977 - val_loss: 1.0511 - val_accuracy: 0.4583
# Epoch 45/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0518 - accuracy: 0.5492 - val_loss: 1.0411 - val_accuracy: 0.4306
# Epoch 46/100
# 10/10 [==============================] - 3s 335ms/step - loss: 1.0195 - accuracy: 0.5542 - val_loss: 1.0340 - val_accuracy: 0.4583
# Epoch 47/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.0194 - accuracy: 0.5284 - val_loss: 1.0297 - val_accuracy: 0.4583
# Epoch 48/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.0124 - accuracy: 0.5412 - val_loss: 1.0221 - val_accuracy: 0.4444
# Epoch 49/100
# 10/10 [==============================] - 3s 338ms/step - loss: 1.0237 - accuracy: 0.5320 - val_loss: 1.0215 - val_accuracy: 0.4444
# Epoch 50/100
# 10/10 [==============================] - 3s 336ms/step - loss: 1.0369 - accuracy: 0.4981 - val_loss: 1.0204 - val_accuracy: 0.4444
# Epoch 51/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.9868 - accuracy: 0.5519 - val_loss: 1.0235 - val_accuracy: 0.4444
# Epoch 52/100
# 10/10 [==============================] - 3s 351ms/step - loss: 0.9843 - accuracy: 0.5519 - val_loss: 1.0249 - val_accuracy: 0.4167
# Epoch 53/100
# 10/10 [==============================] - 4s 357ms/step - loss: 1.0266 - accuracy: 0.5281 - val_loss: 1.0364 - val_accuracy: 0.4167
# Epoch 54/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.0273 - accuracy: 0.5293 - val_loss: 1.0364 - val_accuracy: 0.4167
# Epoch 55/100
# 10/10 [==============================] - 4s 362ms/step - loss: 1.0304 - accuracy: 0.5298 - val_loss: 1.0388 - val_accuracy: 0.4306
# Epoch 56/100
# 10/10 [==============================] - 3s 350ms/step - loss: 1.0027 - accuracy: 0.5595 - val_loss: 1.0448 - val_accuracy: 0.4167
# Epoch 57/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.9615 - accuracy: 0.5476 - val_loss: 1.0333 - val_accuracy: 0.4028
# Epoch 58/100
# 10/10 [==============================] - 4s 384ms/step - loss: 1.0009 - accuracy: 0.5850 - val_loss: 1.0342 - val_accuracy: 0.4028
# Epoch 59/100
# 10/10 [==============================] - 4s 361ms/step - loss: 1.0147 - accuracy: 0.5576 - val_loss: 1.0311 - val_accuracy: 0.4028
# Epoch 60/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.9996 - accuracy: 0.5542 - val_loss: 1.0217 - val_accuracy: 0.3889
# Epoch 61/100
# 10/10 [==============================] - 4s 347ms/step - loss: 1.0157 - accuracy: 0.5466 - val_loss: 1.0229 - val_accuracy: 0.3889
# Epoch 62/100
# 10/10 [==============================] - 4s 378ms/step - loss: 1.0057 - accuracy: 0.5735 - val_loss: 1.0207 - val_accuracy: 0.4167
# Epoch 63/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9989 - accuracy: 0.5551 - val_loss: 1.0229 - val_accuracy: 0.4167
# Epoch 64/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.0069 - accuracy: 0.5317 - val_loss: 1.0235 - val_accuracy: 0.4028
# Epoch 65/100
# 10/10 [==============================] - 4s 455ms/step - loss: 0.9584 - accuracy: 0.5827 - val_loss: 1.0282 - val_accuracy: 0.4028
# Epoch 66/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.9559 - accuracy: 0.5716 - val_loss: 1.0286 - val_accuracy: 0.4167
# Epoch 67/100
# 10/10 [==============================] - 3s 338ms/step - loss: 1.0003 - accuracy: 0.5392 - val_loss: 1.0230 - val_accuracy: 0.4444
# Epoch 68/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9578 - accuracy: 0.5494 - val_loss: 1.0170 - val_accuracy: 0.4306
# Epoch 69/100
# 10/10 [==============================] - 4s 373ms/step - loss: 1.0187 - accuracy: 0.5618 - val_loss: 1.0147 - val_accuracy: 0.4306
# Epoch 70/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.9591 - accuracy: 0.5564 - val_loss: 1.0183 - val_accuracy: 0.4583
# Epoch 71/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9574 - accuracy: 0.5661 - val_loss: 1.0067 - val_accuracy: 0.4861
# Epoch 72/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9889 - accuracy: 0.5648 - val_loss: 1.0004 - val_accuracy: 0.4722
# Epoch 73/100
# 10/10 [==============================] - 3s 351ms/step - loss: 0.9745 - accuracy: 0.5589 - val_loss: 1.0019 - val_accuracy: 0.4722
# Epoch 74/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.9311 - accuracy: 0.5913 - val_loss: 1.0036 - val_accuracy: 0.4306
# Epoch 75/100
# 10/10 [==============================] - 3s 355ms/step - loss: 0.9580 - accuracy: 0.5558 - val_loss: 1.0081 - val_accuracy: 0.4306
# Epoch 76/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.0022 - accuracy: 0.5469 - val_loss: 1.0092 - val_accuracy: 0.4444
# Epoch 77/100
# 10/10 [==============================] - 3s 352ms/step - loss: 0.9566 - accuracy: 0.5756 - val_loss: 1.0202 - val_accuracy: 0.4444
# Epoch 78/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.9318 - accuracy: 0.6044 - val_loss: 1.0140 - val_accuracy: 0.4444
# Epoch 79/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.9171 - accuracy: 0.6007 - val_loss: 1.0127 - val_accuracy: 0.4722
# Epoch 80/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9026 - accuracy: 0.6009 - val_loss: 1.0173 - val_accuracy: 0.4722
# Epoch 81/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.9284 - accuracy: 0.5874 - val_loss: 0.9965 - val_accuracy: 0.4722
# Epoch 82/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.9219 - accuracy: 0.6050 - val_loss: 0.9908 - val_accuracy: 0.4722
# Epoch 83/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9328 - accuracy: 0.5846 - val_loss: 0.9937 - val_accuracy: 0.4722
# Epoch 84/100
# 10/10 [==============================] - 3s 354ms/step - loss: 0.8999 - accuracy: 0.5806 - val_loss: 0.9971 - val_accuracy: 0.4722
# Epoch 85/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.9309 - accuracy: 0.5815 - val_loss: 0.9903 - val_accuracy: 0.4722
# Epoch 86/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9320 - accuracy: 0.5902 - val_loss: 0.9928 - val_accuracy: 0.4444
# Epoch 87/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.8977 - accuracy: 0.6030 - val_loss: 1.0021 - val_accuracy: 0.4583
# Epoch 88/100
# 10/10 [==============================] - 3s 359ms/step - loss: 0.9092 - accuracy: 0.5978 - val_loss: 0.9967 - val_accuracy: 0.4722
# Epoch 89/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.9536 - accuracy: 0.6031 - val_loss: 1.0004 - val_accuracy: 0.4722
# Epoch 90/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.9286 - accuracy: 0.5984 - val_loss: 0.9991 - val_accuracy: 0.4861
# Epoch 91/100
# 10/10 [==============================] - 3s 350ms/step - loss: 0.9725 - accuracy: 0.5487 - val_loss: 1.0095 - val_accuracy: 0.4861
# Epoch 92/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.9151 - accuracy: 0.6075 - val_loss: 1.0074 - val_accuracy: 0.4861
# Epoch 93/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.8362 - accuracy: 0.6382 - val_loss: 1.0029 - val_accuracy: 0.5000
# Epoch 94/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.9569 - accuracy: 0.6017 - val_loss: 1.0168 - val_accuracy: 0.4861
# Epoch 95/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.9447 - accuracy: 0.5538 - val_loss: 1.0069 - val_accuracy: 0.5000
# Epoch 96/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.9299 - accuracy: 0.5685 - val_loss: 0.9999 - val_accuracy: 0.4861
# Epoch 97/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.9513 - accuracy: 0.5669 - val_loss: 0.9902 - val_accuracy: 0.4861
# Epoch 98/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.9223 - accuracy: 0.5864 - val_loss: 0.9915 - val_accuracy: 0.4861
# Epoch 99/100
# 10/10 [==============================] - 3s 355ms/step - loss: 0.8744 - accuracy: 0.6276 - val_loss: 0.9897 - val_accuracy: 0.5000
# Epoch 100/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.8891 - accuracy: 0.6062 - val_loss: 0.9841 - val_accuracy: 0.4861

# %%
#for model3
t_model6.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history6 = t_model6.fit(train_dataset,shuffle=True,validation_data=valid_dataset, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 15s 692ms/step - loss: 2.1738 - accuracy: 0.2733 - val_loss: 1.5220 - val_accuracy: 0.2361
# Epoch 2/100
# 10/10 [==============================] - 3s 336ms/step - loss: 1.8826 - accuracy: 0.2398 - val_loss: 1.4955 - val_accuracy: 0.2500
# Epoch 3/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.7305 - accuracy: 0.2503 - val_loss: 1.4665 - val_accuracy: 0.2778
# Epoch 4/100
# 10/10 [==============================] - 3s 330ms/step - loss: 1.6014 - accuracy: 0.3171 - val_loss: 1.4427 - val_accuracy: 0.3056
# Epoch 5/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.4642 - accuracy: 0.3361 - val_loss: 1.4166 - val_accuracy: 0.2917
# Epoch 6/100
# 10/10 [==============================] - 3s 335ms/step - loss: 1.4386 - accuracy: 0.3629 - val_loss: 1.3981 - val_accuracy: 0.3056
# Epoch 7/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.3261 - accuracy: 0.3495 - val_loss: 1.3797 - val_accuracy: 0.3056
# Epoch 8/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.3374 - accuracy: 0.3720 - val_loss: 1.3556 - val_accuracy: 0.3194
# Epoch 9/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.3222 - accuracy: 0.3694 - val_loss: 1.3323 - val_accuracy: 0.3194
# Epoch 10/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.3167 - accuracy: 0.3822 - val_loss: 1.3114 - val_accuracy: 0.3333
# Epoch 11/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.2372 - accuracy: 0.4259 - val_loss: 1.3017 - val_accuracy: 0.3750
# Epoch 12/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.2421 - accuracy: 0.3993 - val_loss: 1.2942 - val_accuracy: 0.4028
# Epoch 13/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.1890 - accuracy: 0.4256 - val_loss: 1.2856 - val_accuracy: 0.3889
# Epoch 14/100
# 10/10 [==============================] - 4s 353ms/step - loss: 1.2276 - accuracy: 0.4311 - val_loss: 1.2716 - val_accuracy: 0.3750
# Epoch 15/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.2001 - accuracy: 0.4385 - val_loss: 1.2614 - val_accuracy: 0.3750
# Epoch 16/100
# 10/10 [==============================] - 3s 346ms/step - loss: 1.1945 - accuracy: 0.4334 - val_loss: 1.2491 - val_accuracy: 0.3750
# Epoch 17/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.1877 - accuracy: 0.4522 - val_loss: 1.2408 - val_accuracy: 0.3889
# Epoch 18/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.1984 - accuracy: 0.4357 - val_loss: 1.2353 - val_accuracy: 0.3750
# Epoch 19/100
# 10/10 [==============================] - 3s 342ms/step - loss: 1.2227 - accuracy: 0.4285 - val_loss: 1.2276 - val_accuracy: 0.3889
# Epoch 20/100
# 10/10 [==============================] - 3s 339ms/step - loss: 1.1509 - accuracy: 0.5037 - val_loss: 1.2169 - val_accuracy: 0.3750
# Epoch 21/100
# 10/10 [==============================] - 3s 326ms/step - loss: 1.1333 - accuracy: 0.4748 - val_loss: 1.2052 - val_accuracy: 0.3611
# Epoch 22/100
# 10/10 [==============================] - 3s 323ms/step - loss: 1.2059 - accuracy: 0.4435 - val_loss: 1.1933 - val_accuracy: 0.3750
# Epoch 23/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.1701 - accuracy: 0.4468 - val_loss: 1.1832 - val_accuracy: 0.3750
# Epoch 24/100
# 10/10 [==============================] - 3s 330ms/step - loss: 1.1656 - accuracy: 0.4552 - val_loss: 1.1749 - val_accuracy: 0.3889
# Epoch 25/100
# 10/10 [==============================] - 3s 322ms/step - loss: 1.1728 - accuracy: 0.4459 - val_loss: 1.1704 - val_accuracy: 0.3889
# Epoch 26/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.1276 - accuracy: 0.4715 - val_loss: 1.1686 - val_accuracy: 0.4167
# Epoch 27/100
# 10/10 [==============================] - 3s 337ms/step - loss: 1.1283 - accuracy: 0.4834 - val_loss: 1.1645 - val_accuracy: 0.4028
# Epoch 28/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.1058 - accuracy: 0.4640 - val_loss: 1.1690 - val_accuracy: 0.3889
# Epoch 29/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.1588 - accuracy: 0.4575 - val_loss: 1.1618 - val_accuracy: 0.4167
# Epoch 30/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0592 - accuracy: 0.5201 - val_loss: 1.1521 - val_accuracy: 0.4167
# Epoch 31/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.0652 - accuracy: 0.5294 - val_loss: 1.1484 - val_accuracy: 0.4167
# Epoch 32/100
# 10/10 [==============================] - 3s 345ms/step - loss: 1.1123 - accuracy: 0.4913 - val_loss: 1.1396 - val_accuracy: 0.4167
# Epoch 33/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.1229 - accuracy: 0.4738 - val_loss: 1.1304 - val_accuracy: 0.4167
# Epoch 34/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.1083 - accuracy: 0.4873 - val_loss: 1.1275 - val_accuracy: 0.4167
# Epoch 35/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.1254 - accuracy: 0.4624 - val_loss: 1.1277 - val_accuracy: 0.4306
# Epoch 36/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0711 - accuracy: 0.5406 - val_loss: 1.1250 - val_accuracy: 0.4722
# Epoch 37/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0691 - accuracy: 0.5156 - val_loss: 1.1149 - val_accuracy: 0.4583
# Epoch 38/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0261 - accuracy: 0.5311 - val_loss: 1.1083 - val_accuracy: 0.4583
# Epoch 39/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0672 - accuracy: 0.4731 - val_loss: 1.1035 - val_accuracy: 0.4583
# Epoch 40/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0891 - accuracy: 0.4978 - val_loss: 1.1034 - val_accuracy: 0.4444
# Epoch 41/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.0474 - accuracy: 0.5337 - val_loss: 1.0946 - val_accuracy: 0.4583
# Epoch 42/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0855 - accuracy: 0.4817 - val_loss: 1.0946 - val_accuracy: 0.4722
# Epoch 43/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0692 - accuracy: 0.4808 - val_loss: 1.1102 - val_accuracy: 0.4722
# Epoch 44/100
# 10/10 [==============================] - 3s 344ms/step - loss: 1.0462 - accuracy: 0.5112 - val_loss: 1.1157 - val_accuracy: 0.4583
# Epoch 45/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0216 - accuracy: 0.5531 - val_loss: 1.1132 - val_accuracy: 0.4583
# Epoch 46/100
# 10/10 [==============================] - 3s 323ms/step - loss: 1.0832 - accuracy: 0.4840 - val_loss: 1.0993 - val_accuracy: 0.4583
# Epoch 47/100
# 10/10 [==============================] - 3s 326ms/step - loss: 1.0459 - accuracy: 0.5463 - val_loss: 1.0995 - val_accuracy: 0.4306
# Epoch 48/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0802 - accuracy: 0.4954 - val_loss: 1.0925 - val_accuracy: 0.4444
# Epoch 49/100
# 10/10 [==============================] - 3s 324ms/step - loss: 1.0435 - accuracy: 0.5085 - val_loss: 1.0838 - val_accuracy: 0.4722
# Epoch 50/100
# 10/10 [==============================] - 3s 362ms/step - loss: 1.0649 - accuracy: 0.5265 - val_loss: 1.0762 - val_accuracy: 0.4583
# Epoch 51/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0084 - accuracy: 0.5346 - val_loss: 1.0726 - val_accuracy: 0.4583
# Epoch 52/100
# 10/10 [==============================] - 3s 328ms/step - loss: 1.0229 - accuracy: 0.5069 - val_loss: 1.0622 - val_accuracy: 0.4722
# Epoch 53/100
# 10/10 [==============================] - 3s 325ms/step - loss: 0.9943 - accuracy: 0.5631 - val_loss: 1.0594 - val_accuracy: 0.4583
# Epoch 54/100
# 10/10 [==============================] - 3s 324ms/step - loss: 1.0029 - accuracy: 0.5388 - val_loss: 1.0606 - val_accuracy: 0.4583
# Epoch 55/100
# 10/10 [==============================] - 3s 333ms/step - loss: 1.0242 - accuracy: 0.5245 - val_loss: 1.0491 - val_accuracy: 0.4722
# Epoch 56/100
# 10/10 [==============================] - 3s 359ms/step - loss: 0.9708 - accuracy: 0.5494 - val_loss: 1.0489 - val_accuracy: 0.4861
# Epoch 57/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.9730 - accuracy: 0.5565 - val_loss: 1.0486 - val_accuracy: 0.5000
# Epoch 58/100
# 10/10 [==============================] - 3s 333ms/step - loss: 1.0270 - accuracy: 0.5262 - val_loss: 1.0446 - val_accuracy: 0.5000
# Epoch 59/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9917 - accuracy: 0.5387 - val_loss: 1.0435 - val_accuracy: 0.4722
# Epoch 60/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9648 - accuracy: 0.5645 - val_loss: 1.0490 - val_accuracy: 0.4722
# Epoch 61/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.9587 - accuracy: 0.5826 - val_loss: 1.0470 - val_accuracy: 0.4722
# Epoch 62/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9441 - accuracy: 0.5525 - val_loss: 1.0418 - val_accuracy: 0.4861
# Epoch 63/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0165 - accuracy: 0.5146 - val_loss: 1.0396 - val_accuracy: 0.4583
# Epoch 64/100
# 10/10 [==============================] - 3s 329ms/step - loss: 0.9649 - accuracy: 0.5545 - val_loss: 1.0337 - val_accuracy: 0.4722
# Epoch 65/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.9615 - accuracy: 0.5638 - val_loss: 1.0273 - val_accuracy: 0.4861
# Epoch 66/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9646 - accuracy: 0.5486 - val_loss: 1.0272 - val_accuracy: 0.4722
# Epoch 67/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9424 - accuracy: 0.5746 - val_loss: 1.0266 - val_accuracy: 0.4861
# Epoch 68/100
# 10/10 [==============================] - 3s 340ms/step - loss: 1.0032 - accuracy: 0.5385 - val_loss: 1.0203 - val_accuracy: 0.5139
# Epoch 69/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.9742 - accuracy: 0.5816 - val_loss: 1.0172 - val_accuracy: 0.5139
# Epoch 70/100
# 10/10 [==============================] - 3s 335ms/step - loss: 1.0009 - accuracy: 0.5300 - val_loss: 1.0263 - val_accuracy: 0.5139
# Epoch 71/100
# 10/10 [==============================] - 3s 330ms/step - loss: 0.9327 - accuracy: 0.5778 - val_loss: 1.0346 - val_accuracy: 0.5278
# Epoch 72/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9403 - accuracy: 0.6041 - val_loss: 1.0382 - val_accuracy: 0.5278
# Epoch 73/100
# 10/10 [==============================] - 3s 329ms/step - loss: 0.9612 - accuracy: 0.5500 - val_loss: 1.0309 - val_accuracy: 0.5139
# Epoch 74/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.0497 - accuracy: 0.5066 - val_loss: 1.0294 - val_accuracy: 0.5139
# Epoch 75/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9442 - accuracy: 0.5614 - val_loss: 1.0373 - val_accuracy: 0.5139
# Epoch 76/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9721 - accuracy: 0.5672 - val_loss: 1.0260 - val_accuracy: 0.5278
# Epoch 77/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.9115 - accuracy: 0.5513 - val_loss: 1.0148 - val_accuracy: 0.4722
# Epoch 78/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9186 - accuracy: 0.5788 - val_loss: 1.0130 - val_accuracy: 0.4861
# Epoch 79/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9200 - accuracy: 0.5995 - val_loss: 1.0153 - val_accuracy: 0.4722
# Epoch 80/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9823 - accuracy: 0.5410 - val_loss: 1.0074 - val_accuracy: 0.5139
# Epoch 81/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.9571 - accuracy: 0.5758 - val_loss: 0.9992 - val_accuracy: 0.5139
# Epoch 82/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9252 - accuracy: 0.5728 - val_loss: 0.9928 - val_accuracy: 0.5139
# Epoch 83/100
# 10/10 [==============================] - 3s 327ms/step - loss: 0.9309 - accuracy: 0.6032 - val_loss: 1.0011 - val_accuracy: 0.5417
# Epoch 84/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9366 - accuracy: 0.5648 - val_loss: 1.0126 - val_accuracy: 0.5000
# Epoch 85/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.9380 - accuracy: 0.5813 - val_loss: 1.0173 - val_accuracy: 0.4861
# Epoch 86/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.9227 - accuracy: 0.5772 - val_loss: 1.0051 - val_accuracy: 0.5139
# Epoch 87/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.8991 - accuracy: 0.6040 - val_loss: 0.9992 - val_accuracy: 0.5278
# Epoch 88/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.8962 - accuracy: 0.6394 - val_loss: 0.9882 - val_accuracy: 0.5139
# Epoch 89/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.9233 - accuracy: 0.6017 - val_loss: 0.9973 - val_accuracy: 0.5278
# Epoch 90/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.9236 - accuracy: 0.5642 - val_loss: 1.0147 - val_accuracy: 0.5139
# Epoch 91/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.8932 - accuracy: 0.5936 - val_loss: 1.0152 - val_accuracy: 0.5000
# Epoch 92/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.9832 - accuracy: 0.5625 - val_loss: 1.0049 - val_accuracy: 0.4861
# Epoch 93/100
# 10/10 [==============================] - 3s 325ms/step - loss: 0.9215 - accuracy: 0.5857 - val_loss: 0.9968 - val_accuracy: 0.4722
# Epoch 94/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.9347 - accuracy: 0.5755 - val_loss: 0.9882 - val_accuracy: 0.4583
# Epoch 95/100
# 10/10 [==============================] - 3s 319ms/step - loss: 0.9239 - accuracy: 0.5685 - val_loss: 0.9769 - val_accuracy: 0.4722
# Epoch 96/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9384 - accuracy: 0.5963 - val_loss: 0.9849 - val_accuracy: 0.4722
# Epoch 97/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9180 - accuracy: 0.6220 - val_loss: 0.9740 - val_accuracy: 0.4861
# Epoch 98/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.8982 - accuracy: 0.6084 - val_loss: 0.9746 - val_accuracy: 0.4861
# Epoch 99/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.9470 - accuracy: 0.5825 - val_loss: 0.9744 - val_accuracy: 0.5000
# Epoch 100/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9120 - accuracy: 0.5772 - val_loss: 0.9816 - val_accuracy: 0.5139

# %%
#for model3
t_model7.compile(loss=losses.CategoricalCrossentropy(from_logits=True),optimizer=optimizers.Adam(learning_rate=0.0001),metrics=['accuracy'])
history7 = t_model7.fit(train_dataset, shuffle=True,validation_data=valid_dataset, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 16s 686ms/step - loss: 2.2584 - accuracy: 0.2195 - val_loss: 1.6877 - val_accuracy: 0.2500
# Epoch 2/100
# 10/10 [==============================] - 3s 330ms/step - loss: 1.7555 - accuracy: 0.2707 - val_loss: 1.6023 - val_accuracy: 0.3194
# Epoch 3/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.5241 - accuracy: 0.3053 - val_loss: 1.5415 - val_accuracy: 0.4028
# Epoch 4/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.5518 - accuracy: 0.3488 - val_loss: 1.4623 - val_accuracy: 0.4028
# Epoch 5/100
# 10/10 [==============================] - 4s 352ms/step - loss: 1.4296 - accuracy: 0.3417 - val_loss: 1.4104 - val_accuracy: 0.4444
# Epoch 6/100
# 10/10 [==============================] - 3s 324ms/step - loss: 1.4093 - accuracy: 0.3384 - val_loss: 1.3648 - val_accuracy: 0.4306
# Epoch 7/100
# 10/10 [==============================] - 3s 322ms/step - loss: 1.3546 - accuracy: 0.3770 - val_loss: 1.3387 - val_accuracy: 0.4306
# Epoch 8/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.3396 - accuracy: 0.3944 - val_loss: 1.3221 - val_accuracy: 0.4306
# Epoch 9/100
# 10/10 [==============================] - 3s 322ms/step - loss: 1.3317 - accuracy: 0.3672 - val_loss: 1.3145 - val_accuracy: 0.4167
# Epoch 10/100
# 10/10 [==============================] - 3s 339ms/step - loss: 1.3251 - accuracy: 0.3768 - val_loss: 1.2981 - val_accuracy: 0.4444
# Epoch 11/100
# 10/10 [==============================] - 3s 354ms/step - loss: 1.2875 - accuracy: 0.4028 - val_loss: 1.2832 - val_accuracy: 0.4722
# Epoch 12/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.2362 - accuracy: 0.4277 - val_loss: 1.2750 - val_accuracy: 0.4861
# Epoch 13/100
# 10/10 [==============================] - 4s 352ms/step - loss: 1.2062 - accuracy: 0.4235 - val_loss: 1.2778 - val_accuracy: 0.4583
# Epoch 14/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.2339 - accuracy: 0.4327 - val_loss: 1.2650 - val_accuracy: 0.5000
# Epoch 15/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.2008 - accuracy: 0.4648 - val_loss: 1.2553 - val_accuracy: 0.4861
# Epoch 16/100
# 10/10 [==============================] - 3s 335ms/step - loss: 1.1774 - accuracy: 0.4618 - val_loss: 1.2479 - val_accuracy: 0.4861
# Epoch 17/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.2150 - accuracy: 0.4445 - val_loss: 1.2431 - val_accuracy: 0.5000
# Epoch 18/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.1849 - accuracy: 0.4846 - val_loss: 1.2308 - val_accuracy: 0.5000
# Epoch 19/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.1801 - accuracy: 0.4400 - val_loss: 1.2192 - val_accuracy: 0.5000
# Epoch 20/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.2073 - accuracy: 0.4569 - val_loss: 1.2107 - val_accuracy: 0.5000
# Epoch 21/100
# 10/10 [==============================] - 3s 319ms/step - loss: 1.1354 - accuracy: 0.4522 - val_loss: 1.1973 - val_accuracy: 0.4861
# Epoch 22/100
# 10/10 [==============================] - 3s 335ms/step - loss: 1.0883 - accuracy: 0.5124 - val_loss: 1.1865 - val_accuracy: 0.5000
# Epoch 23/100
# 10/10 [==============================] - 3s 341ms/step - loss: 1.1545 - accuracy: 0.4662 - val_loss: 1.1790 - val_accuracy: 0.5000
# Epoch 24/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.1275 - accuracy: 0.4781 - val_loss: 1.1799 - val_accuracy: 0.4861
# Epoch 25/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0888 - accuracy: 0.5332 - val_loss: 1.1704 - val_accuracy: 0.4722
# Epoch 26/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.1179 - accuracy: 0.4906 - val_loss: 1.1584 - val_accuracy: 0.4861
# Epoch 27/100
# 10/10 [==============================] - 3s 328ms/step - loss: 1.1305 - accuracy: 0.4895 - val_loss: 1.1444 - val_accuracy: 0.4861
# Epoch 28/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0873 - accuracy: 0.5357 - val_loss: 1.1369 - val_accuracy: 0.4861
# Epoch 29/100
# 10/10 [==============================] - 3s 333ms/step - loss: 1.1023 - accuracy: 0.5285 - val_loss: 1.1269 - val_accuracy: 0.4861
# Epoch 30/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.1022 - accuracy: 0.5098 - val_loss: 1.1305 - val_accuracy: 0.5000
# Epoch 31/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.0965 - accuracy: 0.5023 - val_loss: 1.1198 - val_accuracy: 0.5000
# Epoch 32/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.1094 - accuracy: 0.5272 - val_loss: 1.1190 - val_accuracy: 0.5000
# Epoch 33/100
# 10/10 [==============================] - 3s 332ms/step - loss: 1.0591 - accuracy: 0.5154 - val_loss: 1.1203 - val_accuracy: 0.5000
# Epoch 34/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.1117 - accuracy: 0.4927 - val_loss: 1.1085 - val_accuracy: 0.4722
# Epoch 35/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.0387 - accuracy: 0.5338 - val_loss: 1.0904 - val_accuracy: 0.5000
# Epoch 36/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0923 - accuracy: 0.4917 - val_loss: 1.0950 - val_accuracy: 0.5000
# Epoch 37/100
# 10/10 [==============================] - 3s 335ms/step - loss: 1.0539 - accuracy: 0.5306 - val_loss: 1.0971 - val_accuracy: 0.5000
# Epoch 38/100
# 10/10 [==============================] - 3s 339ms/step - loss: 1.0799 - accuracy: 0.4894 - val_loss: 1.0894 - val_accuracy: 0.4861
# Epoch 39/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.0664 - accuracy: 0.5240 - val_loss: 1.0837 - val_accuracy: 0.4861
# Epoch 40/100
# 10/10 [==============================] - 3s 344ms/step - loss: 1.0740 - accuracy: 0.5249 - val_loss: 1.0663 - val_accuracy: 0.5000
# Epoch 41/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.9829 - accuracy: 0.5449 - val_loss: 1.0642 - val_accuracy: 0.5000
# Epoch 42/100
# 10/10 [==============================] - 3s 331ms/step - loss: 1.0275 - accuracy: 0.5435 - val_loss: 1.0660 - val_accuracy: 0.5000
# Epoch 43/100
# 10/10 [==============================] - 3s 319ms/step - loss: 0.9944 - accuracy: 0.5474 - val_loss: 1.0642 - val_accuracy: 0.5139
# Epoch 44/100
# 10/10 [==============================] - 3s 334ms/step - loss: 1.0378 - accuracy: 0.5520 - val_loss: 1.0479 - val_accuracy: 0.5139
# Epoch 45/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.9655 - accuracy: 0.5886 - val_loss: 1.0518 - val_accuracy: 0.5139
# Epoch 46/100
# 10/10 [==============================] - 3s 330ms/step - loss: 1.0130 - accuracy: 0.5539 - val_loss: 1.0636 - val_accuracy: 0.5000
# Epoch 47/100
# 10/10 [==============================] - 3s 330ms/step - loss: 1.0485 - accuracy: 0.5303 - val_loss: 1.0717 - val_accuracy: 0.4861
# Epoch 48/100
# 10/10 [==============================] - 3s 325ms/step - loss: 0.9401 - accuracy: 0.5807 - val_loss: 1.0811 - val_accuracy: 0.4861
# Epoch 49/100
# 10/10 [==============================] - 3s 329ms/step - loss: 0.9508 - accuracy: 0.5914 - val_loss: 1.0775 - val_accuracy: 0.4722
# Epoch 50/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9997 - accuracy: 0.5709 - val_loss: 1.0727 - val_accuracy: 0.4861
# Epoch 51/100
# 10/10 [==============================] - 3s 329ms/step - loss: 1.0272 - accuracy: 0.5444 - val_loss: 1.0706 - val_accuracy: 0.5000
# Epoch 52/100
# 10/10 [==============================] - 3s 329ms/step - loss: 0.9988 - accuracy: 0.5658 - val_loss: 1.0832 - val_accuracy: 0.5000
# Epoch 53/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9843 - accuracy: 0.5552 - val_loss: 1.0904 - val_accuracy: 0.5000
# Epoch 54/100
# 10/10 [==============================] - 3s 324ms/step - loss: 0.9604 - accuracy: 0.5995 - val_loss: 1.0805 - val_accuracy: 0.4861
# Epoch 55/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.9678 - accuracy: 0.5583 - val_loss: 1.0759 - val_accuracy: 0.4861
# Epoch 56/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.9555 - accuracy: 0.5792 - val_loss: 1.0668 - val_accuracy: 0.4861
# Epoch 57/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0242 - accuracy: 0.5450 - val_loss: 1.0643 - val_accuracy: 0.4861
# Epoch 58/100
# 10/10 [==============================] - 3s 343ms/step - loss: 1.0344 - accuracy: 0.5393 - val_loss: 1.0554 - val_accuracy: 0.4861
# Epoch 59/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9840 - accuracy: 0.5668 - val_loss: 1.0595 - val_accuracy: 0.4861
# Epoch 60/100
# 10/10 [==============================] - 3s 325ms/step - loss: 1.0292 - accuracy: 0.5454 - val_loss: 1.0606 - val_accuracy: 0.4861
# Epoch 61/100
# 10/10 [==============================] - 3s 329ms/step - loss: 0.9905 - accuracy: 0.5809 - val_loss: 1.0557 - val_accuracy: 0.4861
# Epoch 62/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.9636 - accuracy: 0.5652 - val_loss: 1.0422 - val_accuracy: 0.4583
# Epoch 63/100
# 10/10 [==============================] - 3s 326ms/step - loss: 0.9769 - accuracy: 0.5719 - val_loss: 1.0410 - val_accuracy: 0.4861
# Epoch 64/100
# 10/10 [==============================] - 3s 330ms/step - loss: 0.9899 - accuracy: 0.5531 - val_loss: 1.0493 - val_accuracy: 0.4583
# Epoch 65/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9270 - accuracy: 0.6034 - val_loss: 1.0599 - val_accuracy: 0.4583
# Epoch 66/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9520 - accuracy: 0.6233 - val_loss: 1.0624 - val_accuracy: 0.4583
# Epoch 67/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.0118 - accuracy: 0.5546 - val_loss: 1.0511 - val_accuracy: 0.4861
# Epoch 68/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.9693 - accuracy: 0.5586 - val_loss: 1.0367 - val_accuracy: 0.5000
# Epoch 69/100
# 10/10 [==============================] - 3s 327ms/step - loss: 1.0008 - accuracy: 0.5512 - val_loss: 1.0342 - val_accuracy: 0.4861
# Epoch 70/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.9566 - accuracy: 0.5525 - val_loss: 1.0347 - val_accuracy: 0.5139
# Epoch 71/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.9439 - accuracy: 0.6104 - val_loss: 1.0291 - val_accuracy: 0.5139
# Epoch 72/100
# 10/10 [==============================] - 4s 346ms/step - loss: 0.9387 - accuracy: 0.5556 - val_loss: 1.0258 - val_accuracy: 0.4861
# Epoch 73/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9254 - accuracy: 0.5958 - val_loss: 1.0220 - val_accuracy: 0.4861
# Epoch 74/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.9376 - accuracy: 0.5924 - val_loss: 1.0209 - val_accuracy: 0.4861
# Epoch 75/100
# 10/10 [==============================] - 3s 330ms/step - loss: 0.9597 - accuracy: 0.5489 - val_loss: 1.0196 - val_accuracy: 0.5139
# Epoch 76/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.8855 - accuracy: 0.6443 - val_loss: 1.0308 - val_accuracy: 0.5000
# Epoch 77/100
# 10/10 [==============================] - 4s 350ms/step - loss: 0.9487 - accuracy: 0.5554 - val_loss: 1.0280 - val_accuracy: 0.5139
# Epoch 78/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.9613 - accuracy: 0.5762 - val_loss: 1.0290 - val_accuracy: 0.4861
# Epoch 79/100
# 10/10 [==============================] - 3s 330ms/step - loss: 0.9130 - accuracy: 0.6022 - val_loss: 1.0360 - val_accuracy: 0.4861
# Epoch 80/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9127 - accuracy: 0.5892 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 81/100
# 10/10 [==============================] - 3s 329ms/step - loss: 0.9401 - accuracy: 0.6038 - val_loss: 1.0412 - val_accuracy: 0.4861
# Epoch 82/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9285 - accuracy: 0.5941 - val_loss: 1.0353 - val_accuracy: 0.4861
# Epoch 83/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.9006 - accuracy: 0.5968 - val_loss: 1.0353 - val_accuracy: 0.4861
# Epoch 84/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.9437 - accuracy: 0.5516 - val_loss: 1.0327 - val_accuracy: 0.4861
# Epoch 85/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9135 - accuracy: 0.5849 - val_loss: 1.0348 - val_accuracy: 0.4861
# Epoch 86/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.9445 - accuracy: 0.5811 - val_loss: 1.0389 - val_accuracy: 0.4861
# Epoch 87/100
# 10/10 [==============================] - 3s 327ms/step - loss: 0.9001 - accuracy: 0.5919 - val_loss: 1.0405 - val_accuracy: 0.5000
# Epoch 88/100
# 10/10 [==============================] - 3s 323ms/step - loss: 0.9493 - accuracy: 0.5929 - val_loss: 1.0234 - val_accuracy: 0.4583
# Epoch 89/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.9164 - accuracy: 0.5932 - val_loss: 1.0159 - val_accuracy: 0.4722
# Epoch 90/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.9510 - accuracy: 0.5653 - val_loss: 1.0125 - val_accuracy: 0.4861
# Epoch 91/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.9016 - accuracy: 0.5887 - val_loss: 1.0042 - val_accuracy: 0.4722
# Epoch 92/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.9677 - accuracy: 0.5809 - val_loss: 0.9988 - val_accuracy: 0.5000
# Epoch 93/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.9395 - accuracy: 0.5891 - val_loss: 1.0075 - val_accuracy: 0.5000
# Epoch 94/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.8520 - accuracy: 0.6223 - val_loss: 1.0202 - val_accuracy: 0.5000
# Epoch 95/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.9038 - accuracy: 0.6029 - val_loss: 1.0219 - val_accuracy: 0.4861
# Epoch 96/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.9301 - accuracy: 0.5890 - val_loss: 1.0162 - val_accuracy: 0.5000
# Epoch 97/100
# 10/10 [==============================] - 3s 328ms/step - loss: 0.8719 - accuracy: 0.5964 - val_loss: 1.0088 - val_accuracy: 0.5000
# Epoch 98/100
# 10/10 [==============================] - 3s 323ms/step - loss: 0.9662 - accuracy: 0.6008 - val_loss: 1.0083 - val_accuracy: 0.4722
# Epoch 99/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.9614 - accuracy: 0.5525 - val_loss: 1.0130 - val_accuracy: 0.4722
# Epoch 100/100
# 10/10 [==============================] - 3s 324ms/step - loss: 0.9078 - accuracy: 0.5914 - val_loss: 1.0258 - val_accuracy: 0.4861

# %%
fig1 = plt.figure()
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_loss'])
plt.plot(history2.history['accuracy'])
#plt.plot(history2.history['val_loss'])
plt.plot(history3.history['accuracy'])
#plt.plot(history3.history['val_loss'])
plt.plot(history4.history['accuracy'])
#plt.plot(history4.history['val_loss'])
plt.plot(history5.history['accuracy'])
#plt.plot(history5.history['val_loss'])
plt.plot(history6.history['accuracy'])
#plt.plot(history6.history['val_loss'])
plt.plot(history7.history['accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['PCS','NCS','PNCS','1st_Layer','2nd_Layer','3rd_Layer','Feature_Extraction'], loc='lower right')
plt.legend(['PCS','NCS','PNCS','1st_Layer','2nd_Layer','3rd_Layer','Feature_Extraction'], loc="center right", bbox_to_anchor=(1.6, 0.5))
fig1.savefig('all_similarity_breast_densenet.eps', dpi=1200, format="eps", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig3 = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
#plt.plot(history.history['val_loss'])
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
#plt.plot(history2.history['val_loss'])
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['PCS_Train','PCS_Val','NCS_Train','NCS_Val','PNCS_Train','PNCS_Val'], loc='upper right')

fig3.savefig('3plots_Loss_breast_densenet.eps', dpi=1200, format="eps", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig3 = plt.figure()
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.plot(history.history['loss'])
#plt.plot(history2.history['val_loss'])
plt.plot(history2.history['loss'])
#plt.plot(history3.history['val_loss'])
#plt.plot(history2.history['loss'])
#plt.plot(history4.history['val_loss'])
plt.plot(history3.history['loss'])
#plt.plot(history5.history['val_loss'])
#plt.plot(history3.history['loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['PCS_Loss','PCS_Val_Loss','NCS_Loss','NCS_Val_Loss','PNCS_Loss','PNCS_Val_Loss'], loc='upper right')
#plt.legend(['PCS','NCS','PNCS'], loc="center right", bbox_to_anchor=(1.6, 0.5))
plt.legend(['PCS','NCS','PNCS'],  loc='upper right')
fig3.savefig('3plots_Loss_breast_data_densenet.eps', dpi=1200, format="eps", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig2 = plt.figure()
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_loss'])
#plt.plot(history.history['accuracy'])
#plt.plot(history2.history['val_loss'])
plt.plot(history2.history['accuracy'])
#plt.plot(history3.history['val_loss'])
#plt.plot(history2.history['accuracy'])
#plt.plot(history4.history['val_loss'])
plt.plot(history3.history['accuracy'])
#plt.plot(history5.history['val_loss'])
#plt.plot(history3.history['accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['PCS_Train','PCS_Val','NCS_Train','NCS_Val','PNCS_Train','PNCS_Val'], loc='upper left')
plt.legend(['PCS','NCS','PNCS'], loc='lower right')
#plt.legend(['PCS_Train','PCS_Val','NCS_Train'], loc="center right", bbox_to_anchor=(1.6, 0.5))
fig2.savefig('3plots_breast_densent.eps', dpi=1200, format="eps", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
